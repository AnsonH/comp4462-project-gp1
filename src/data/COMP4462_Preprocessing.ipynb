# %% [markdown]
# # Import file

# %%
import pandas as pd
import json

df = pd.read_csv("Mass Shootings Dataset.csv", encoding="ISO-8859-1")
df = pd.DataFrame(df).dropna()
df
# Out:
#       S#                             Title  ...   Latitude   Longitude
# 11    12             Ferguson, MO Drive by  ...  38.744217  -90.305391
# 12    13    Forestville, Maryland Drive-by  ...  38.845113  -76.874972
# 13    14                Halifax County, VA  ...  36.765971  -78.928344
# 14    15  Tire-Slashing revenge escalation  ...  39.290385  -76.612189
# 15    16        Chicago Rap video Shootout  ...  41.878114  -87.629798
# ..   ...                               ...  ...        ...         ...
# 393  394    Clara Barton Elementary School  ...  41.839280  -87.688181
# 394  395      New Orleans Police Shootings  ...  30.068724  -89.931474
# 395  396               St. Aloysius Church  ...  47.673674 -117.415984
# 396  397        Rose-Mar College of Beauty  ...  33.422687 -111.816320
# 397  398     University of Texas at Austin  ...  30.198887  -97.844159
#
# [378 rows x 13 columns]

# %% [markdown]
# # Name-entity Recognition (for Word Cloud)

# %%
# !pip install flair

# %%
output = df.to_json(orient="records")
output = json.loads(output)
output
# Out:
# [{'Date': '4/29/2016',
#   'Fatalities': 0,
#   'Gender': 'Unknown',
#   'Injured': 4,
#   'Latitude': 38.744217,
#   'Location': 'Ferguson, Missouri',
#   'Longitude': -90.305391,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 12,
#   'Summary': 'A group of 15 to 20 people was gathered for a memorial for a family member when two cars drove by and opened fire. Four people were injured. No suspects or specific motive or targets.',
#   'Title': 'Ferguson, MO Drive by',
#   'Total victims': 4},
#  {'Date': '4/26/2016',
#   'Fatalities': 1,
#   'Gender': 'Unknown',
#   'Injured': 4,
#   'Latitude': 38.845113,
#   'Location': '42486, ',
#   'Longitude': -76.874972,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 13,
#   'Summary': "Shooter shot from his car at people standing on the street at 1:30 AM. Police don't believe the woman who died was the target, and do not believe the shooting was random.",
#   'Title': 'Forestville, Maryland Drive-by',
#   'Total victims': 5},
#  {'Date': '4/24/2016',
#   'Fatalities': 0,
#   'Gender': 'Male',
#   'Injured': 6,
#   'Latitude': 36.765971,
#   'Location': '42484, ',
#   'Longitude': -78.928344,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 14,
#   'Summary': 'Male shooter fired into crown when a deputy police tried, unsuccessfully to stop him. The deputy fired on the shooter and inured him.',
#   'Title': 'Halifax County, VA',
#   'Total victims': 6},
#  {'Date': '4/21/2016',
#   'Fatalities': 0,
#   'Gender': 'Male',
#   'Injured': 4,
#   'Latitude': 39.290385,
#   'Location': '42481, ',
#   'Longitude': -76.612189,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 15,
#   'Summary': "Shooter was angry over fact that rival families had been slashing each other's cars. Shooter fired into a block party and injured four.",
#   'Title': 'Tire-Slashing revenge escalation',
#   'Total victims': 4},
#  {'Date': '4/19/2016',
#   'Fatalities': 1,
#   'Gender': 'Unknown',
#   'Injured': 4,
#   'Latitude': 41.878114,
#   'Location': '42479, ',
#   'Longitude': -87.629798,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 16,
#   'Summary': 'Group of young men were in a park at 2 in the morning when a male walked up and shot them. One fatality. Four injuries. Shooter is unknown.',
#   'Title': 'Chicago Rap video Shootout',
#   'Total victims': 5},
#  {'Date': '4/19/2016',
#   'Fatalities': 4,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 29.785785,
#   'Location': '42479, ',
#   'Longitude': -95.824396,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 17,
#   'Summary': 'Man killed his wife and two young children before committing suicide. No explanation has been offered',
#   'Title': 'Texas family murder-suicide',
#   'Total victims': 4},
#  {'Date': '4/19/2016',
#   'Fatalities': 1,
#   'Gender': 'Male',
#   'Injured': 4,
#   'Latitude': 34.16204,
#   'Location': '42479, ',
#   'Longitude': -86.475543,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 18,
#   'Summary': "Shooter fired from his car at two different locations along a highway in rural Alabama. He didn't injure any at the first shootout, but injured four at the second. He was killed by police.",
#   'Title': 'Alabama highway random shooting',
#   'Total victims': 4},
#  {'Date': '4/18/2016',
#   'Fatalities': 0,
#   'Gender': 'Unknown',
#   'Injured': 3,
#   'Latitude': 33.77005,
#   'Location': '42478, ',
#   'Longitude': -118.193739,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 19,
#   'Summary': 'Group of men were standing at a street corner when someone came up and fired upon them. One man died, 3 injured. Nothing is known about the shooter.',
#   'Title': 'Long Beach Street murder',
#   'Total victims': 4},
#  {'Date': '4/9/2016',
#   'Fatalities': 0,
#   'Gender': 'Male',
#   'Injured': 4,
#   'Latitude': 35.085334,
#   'Location': '42469, ',
#   'Longitude': -106.605553,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 20,
#   'Summary': 'A Man shot four uninvited party guests who would not leave the party hosted by the shooter. He started firing when they broke windows and started kicking in the door.',
#   'Title': 'Albuquerque, NM House party shooting',
#   'Total victims': 4},
#  {'Date': '4/9/2016',
#   'Fatalities': 0,
#   'Gender': 'Unknown',
#   'Injured': 4,
#   'Latitude': 35.149534,
#   'Location': '42469, ',
#   'Longitude': -90.04898,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 21,
#   'Summary': 'Four people were shot below the waist at a gas station after an altercation broke out at a gas station.',
#   'Title': 'Memphis, TN gas station shooting',
#   'Total victims': 4},
#  {'Date': '4/7/2016',
#   'Fatalities': 0,
#   'Gender': 'Unknown',
#   'Injured': 5,
#   'Latitude': 41.878114,
#   'Location': '42467, ',
#   'Longitude': -87.629798,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 22,
#   'Summary': 'Birthday party bus was dropping off party goers in South Shore Chicago when someone on the street started shooting at them. The bus driver drove off quickly protecting the targets. Unknown motivation. No suspects. ',
#   'Title': 'Chicago Birthday Party Bus Shooting',
#   'Total victims': 5},
#  {'Date': '4/1/2016',
#   'Fatalities': 3,
#   'Gender': 'Male',
#   'Injured': 1,
#   'Latitude': 35.085334,
#   'Location': '42461, ',
#   'Longitude': -106.605553,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Asian American',
#   'S#': 23,
#   'Summary': 'The shooter killed two of his nephews at the restaurant they owned. He shot and injured his brother. Then killed himself.',
#   'Title': 'Albuquerque, NM Family restaurant shooting',
#   'Total victims': 3},
#  {'Date': '3/31/2016',
#   'Fatalities': 2,
#   'Gender': 'Male',
#   'Injured': 2,
#   'Latitude': 37.540725,
#   'Location': 'Richmond, Virginia',
#   'Longitude': -77.436048,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 24,
#   'Summary': 'A man fatally shot a Virginia state trooper at a Greyhound bus station before the gunman was killed by other troopers. The trooper had been participating with about a dozen other troopers in a training exercise at the bus station when a brief encounter with the gunman quickly turned violent. The shooter had been sitting in the restaurant at the bus station and went to his luggage near the front entrance. He began to walk away from his bags. The trooper approached the suspect. Shortly after the two talked for a few seconds, with the suspect to the trooper\x92s immediate right, the shooter pulled a gun from his waistband and shot the trooper from just inches away.',
#   'Title': 'Richmond, Virginia',
#   'Total victims': 3},
#  {'Date': '3/26/2016',
#   'Fatalities': 3,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 36.099039,
#   'Location': 'Louisburg, North Carolina',
#   'Longitude': -78.301106,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 25,
#   'Summary': 'Three people were killed in a shooting at a home. The shooter was on probation after being released from prison about two weeks ago. He was required to wear an ankle bracelet that monitored his whereabouts, but removed the device on Friday \x97 the day before the shootings.',
#   'Title': 'Louisburg, North Carolina',
#   'Total victims': 3},
#  {'Date': '3/25/2016',
#   'Fatalities': 2,
#   'Gender': 'Male',
#   'Injured': 2,
#   'Latitude': 35.242302,
#   'Location': 'Lawrenceburg, Tennessee',
#   'Longitude': -87.334739,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 26,
#   'Summary': 'The man was suspected of shooting his wife and two sons on Friday morning at the family\x92s home. All three victims were initially shot inside the residence with a shotgun.',
#   'Title': 'Lawrenceburg, Tennessee',
#   'Total victims': 3},
#  {'Date': '3/25/2016',
#   'Fatalities': 2,
#   'Gender': 'Male',
#   'Injured': 2,
#   'Latitude': 34.759257,
#   'Location': '42454, ',
#   'Longitude': -86.602493,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 27,
#   'Summary': 'Husband murders his wife and injures his two sons at their home in rural Alabama, then commits suicide',
#   'Title': 'Greenhill, AL Family murder-suicide',
#   'Total victims': 3},
#  {'Date': '3/21/2016',
#   'Fatalities': 4,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 33.635662,
#   'Location': 'Sherman, Texas',
#   'Longitude': -96.60888,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 28,
#   'Summary': 'A man shot and killed his wife and two boys, then he turned the gun on himself.',
#   'Title': 'Sherman, Texas',
#   'Total victims': 3},
#  {'Date': '3/21/2016',
#   'Fatalities': 4,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 33.635662,
#   'Location': '42450, ',
#   'Longitude': -96.60888,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 29,
#   'Summary': 'Husband murders his wife and two young children in Sherman, TX, then commits suicide',
#   'Title': 'Sherman, TX Family murder-suicide',
#   'Total victims': 3},
#  {'Date': '3/20/2016',
#   'Fatalities': 4,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 38.252665,
#   'Location': 'Louisville, Kentucky',
#   'Longitude': -85.758456,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 30,
#   'Summary': 'A former soldier who fatally shot his wife and two children and set their house on fire before killing himself suffered from post-traumatic stress disorder following a military career that included a stint in Iraq.',
#   'Title': 'Louisville, Kentucky',
#   'Total victims': 3},
#  {'Date': '3/20/2016',
#   'Fatalities': 4,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 38.252665,
#   'Location': '42449, ',
#   'Longitude': -85.758456,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 31,
#   'Summary': 'Husband murders his wife and two children before committing suicide at their Kentucky home',
#   'Title': 'Louisville, KY Family Murder-Suicide',
#   'Total victims': 3},
#  {'Date': '3/19/2016',
#   'Fatalities': 1,
#   'Gender': 'Unknown',
#   'Injured': 4,
#   'Latitude': 26.127586,
#   'Location': 'Plantation, Florida',
#   'Longitude': -80.233104,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 32,
#   'Summary': 'A Spring Break party in a house packed with 400 people ended in gunfire that killed one man and wounded four others.',
#   'Title': 'Plantation, Florida',
#   'Total victims': 5},
#  {'Date': '3/19/2016',
#   'Fatalities': 2,
#   'Gender': 'Male',
#   'Injured': 2,
#   'Latitude': 32.543745,
#   'Location': '42448, ',
#   'Longitude': -86.211913,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 33,
#   'Summary': 'Shooter fired 12 rounds from a semi-automatic handgun that left two dead and two critically injured in a Saturday afternoon drive-by in Wetumpka, Alabama.',
#   'Title': 'Wetumpka Drive-by',
#   'Total victims': 4},
#  {'Date': '3/19/2016',
#   'Fatalities': 1,
#   'Gender': 'Unknown',
#   'Injured': 4,
#   'Latitude': 26.127586,
#   'Location': '42448, ',
#   'Longitude': -80.233104,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 34,
#   'Summary': 'Shooter fired into crowd at a spring break house party with over 400 people, killing one, and injuring four. No one provided any information about the shooter, who escaped.',
#   'Title': 'Spring Break Party shooting',
#   'Total victims': 5},
#  {'Date': '3/15/2016',
#   'Fatalities': 0,
#   'Gender': 'Unknown',
#   'Injured': 4,
#   'Latitude': 33.748995,
#   'Location': '42444, ',
#   'Longitude': -84.387982,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 35,
#   'Summary': 'Two groups of people were asked to leave a nightclub when they started arguing. They were outside the club when they started shooting. Five people were injured. ',
#   'Title': 'Atlanta Nightclub shooting',
#   'Total victims': 4},
#  {'Date': '3/13/2016',
#   'Fatalities': 0,
#   'Gender': 'Unknown',
#   'Injured': 4,
#   'Latitude': 26.640628,
#   'Location': '42442, ',
#   'Longitude': -81.872308,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 36,
#   'Summary': 'Family was celebrating a birthday party when a group of 12 arrived. Fight broke out, four people shot.',
#   'Title': 'Florida Family celebration ends in shooting',
#   'Total victims': 4},
#  {'Date': '3/12/2016',
#   'Fatalities': 2,
#   'Gender': 'Male',
#   'Injured': 2,
#   'Latitude': 34.111223,
#   'Location': '42441, ',
#   'Longitude': -82.867084,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 37,
#   'Summary': 'Domestic dispute led a man to shoot his girlfriend, kill her daughter, and injure a bystander who was trying to help the girlfriend',
#   'Title': 'Elberton, Georgia murder-suicide',
#   'Total victims': 3},
#  {'Date': '3/11/2016',
#   'Fatalities': 0,
#   'Gender': 'Unknown',
#   'Injured': 5,
#   'Latitude': 40.217053,
#   'Location': '42440, ',
#   'Longitude': -74.742938,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 38,
#   'Summary': 'A group of women were arguing on a sidewalk outside of an apartment complex in Trenton, NJ when a black Acura pulled up. Two men got out. And one shot at the women, injuring five. ',
#   'Title': 'Trenton, NJ sidewalk shooting',
#   'Total victims': 5},
#  {'Date': '3/11/2016',
#   'Fatalities': 2,
#   'Gender': 'Unknown',
#   'Injured': 2,
#   'Latitude': 42.331427,
#   'Location': '42440, ',
#   'Longitude': -83.045754,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 39,
#   'Summary': 'Four men were sitting on a porch when a black SUV with three passengers drove by and opened fire in broad daylight. Two of the men died and two were injured. The SUV got away and there are no suspects',
#   'Title': 'Detroit Drive-by',
#   'Total victims': 4},
#  {'Date': '3/9/2016',
#   'Fatalities': 6,
#   'Gender': 'Male',
#   'Injured': 3,
#   'Latitude': 40.440625,
#   'Location': 'Pittsburgh, Pennsylvania',
#   'Longitude': -79.995886,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 40,
#   'Summary': 'Two gunmen working as a team fatally shot five people including a pregnant woman and critically wounded two others at a backyard cookout, with one attacker using a high-velocity rifle to shoot all the victims in the head as they were driven his direction. Authorities later ruled the death of the woman\x92s 8-month-old fetus a homicide and raised the number of fatalities to six.',
#   'Title': 'Pittsburgh, Pennsylvania',
#   'Total victims': 9},
#  {'Date': '3/9/2016',
#   'Fatalities': 5,
#   'Gender': 'Male',
#   'Injured': 3,
#   'Latitude': 40.441736,
#   'Location': '42438, ',
#   'Longitude': -79.881994,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 41,
#   'Summary': 'A family was having a cookout in the backyard of a house when two gunmen came and started shooting. There is one suspected target, but 5 people were killed, including one pregnant woman. The two gunmen fled the scene and have not been identified.',
#   'Title': 'Wilkinsburg BBQ cookout shootout',
#   'Total victims': 8},
#  {'Date': '3/7/2016',
#   'Fatalities': 5,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 39.114053,
#   'Location': 'Kansas City, Kansas',
#   'Longitude': -94.627464,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Some other race',
#   'S#': 42,
#   'Summary': 'Four people were found dead Monday night in a home in Kansas City, Kansas. A fifth man was shot to death Tuesday in Missouri. The shooter lives in a house next door to the home where four people were found shot Monday night. The shooter and the neighbors are all familiar with each other.',
#   'Title': 'Kansas City, Kansas',
#   'Total victims': 5},
#  {'Date': '3/7/2016',
#   'Fatalities': 0,
#   'Gender': 'Unknown',
#   'Injured': 4,
#   'Latitude': 30.22409,
#   'Location': '42436, ',
#   'Longitude': -92.019843,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 43,
#   'Summary': 'Four people shot with non-life-threatening injuries during a drive-by on MLK boulevard in Lafayette, LA. There were multiple shooters in the Ford f-150 truck, truck fled the scene. No leads. ',
#   'Title': 'Lafayette, LA drive by',
#   'Total victims': 4},
#  {'Date': '3/7/2016',
#   'Fatalities': 4,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 39.114053,
#   'Location': '42436, ',
#   'Longitude': -94.627464,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Some other race',
#   'S#': 44,
#   'Summary': 'Shooter killed four people at his next door neighbors house. He fled the scene, but was captured the next day, hiding in a ditch. It is seen as a random act.',
#   'Title': 'Kansas City Home Invasion',
#   'Total victims': 4},
#  {'Date': '3/6/2016',
#   'Fatalities': 1,
#   'Gender': 'Male',
#   'Injured': 6,
#   'Latitude': 42.391764,
#   'Location': 'Chelsea, Massachusetts',
#   'Longitude': -71.032828,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 45,
#   'Summary': 'The shooting happened early Sunday morning during a party in a vacant apartment. The shooter pened fire with one gun at a party of about 50 people in an vacant, three-room apartment. A 19-year-old Chelsea resident was was killed in a shooting that wounded five other teens and a 22-year-old.',
#   'Title': 'Chelsea, Massachusetts',
#   'Total victims': 7},
#  {'Date': '3/6/2016',
#   'Fatalities': 1,
#   'Gender': 'Male',
#   'Injured': 6,
#   'Latitude': 42.391764,
#   'Location': '42435, ',
#   'Longitude': -71.032828,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Some other race',
#   'S#': 46,
#   'Summary': 'Shooter fired upon party of ~50 people at an empty apartment in Chelsea, MA. 1 dead. 6 wounded. Shooters step brother was among those shot',
#   'Title': 'Chelsea, MA empty apartment party shooting',
#   'Total victims': 7},
#  {'Date': '3/6/2016',
#   'Fatalities': 0,
#   'Gender': 'Male',
#   'Injured': 4,
#   'Latitude': 34.023243,
#   'Location': '42435, ',
#   'Longitude': -84.361556,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 47,
#   'Summary': 'Altercation in a hookah bar led a group of seven people to leave in a mini-van. They were followed. When the car stopped, the shooter fired upon the car. Four of the seven sustained non-life-threatening injuries. ',
#   'Title': 'Roswell, GA Hookah shootout',
#   'Total victims': 4},
#  {'Date': '3/5/2016',
#   'Fatalities': 0,
#   'Gender': 'Unknown',
#   'Injured': 4,
#   'Latitude': 37.687176,
#   'Location': '42434, ',
#   'Longitude': -97.330053,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 48,
#   'Summary': 'Altercation led to group of people getting kicked out of a club. Shooting took place around 1am outside the club. Four injured. ',
#   'Title': 'Wichita Nightclub shooting',
#   'Total victims': 4},
#  {'Date': '2/28/2016',
#   'Fatalities': 0,
#   'Gender': 'Male',
#   'Injured': 5,
#   'Latitude': 42.331427,
#   'Location': '42428, ',
#   'Longitude': -83.045754,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 49,
#   'Summary': 'Man apparently inappropriately touched a stripper. He was asked to leave. He waited outside, then shot the stripper and four other people.',
#   'Title': 'Detroit Strip Club Shootout',
#   'Total victims': 5},
#  {'Date': '2/28/2016',
#   'Fatalities': 1,
#   'Gender': 'Male',
#   'Injured': 3,
#   'Latitude': 33.997197,
#   'Location': '42428, ',
#   'Longitude': -117.48548,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Some other race',
#   'S#': 50,
#   'Summary': 'Shooter fired upon group of people in a restaurant parking lot',
#   'Title': 'Riverside restaurant shooting',
#   'Total victims': 4},
#  {'Date': '2/27/2016',
#   'Fatalities': 2,
#   'Gender': 'Male',
#   'Injured': 2,
#   'Latitude': 38.6697,
#   'Location': 'Woodbridge,  Virginia',
#   'Longitude': -77.3524,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 51,
#   'Summary': 'On Saturday of February 27th, three officers arrived to investigate a domestic dispute call, the shooter fired a rifle from the front door of his home, striking all three. Inside the house, police found his wife dead in a bedroom.',
#   'Title': 'Woodbridge, Virginia',
#   'Total victims': 4},
#  {'Date': '2/26/2016',
#   'Fatalities': 5,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 47.5033,
#   'Location': 'Belfair, Washington',
#   'Longitude': -122.931,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 52,
#   'Summary': "At around 9am on Friday morning, a man phoned an officer with the Mason County Sheriff's Office to say that he had shot his family and was going to kill himself next. The man was flushed out of his house when the SWAT team fired tear gas inside. He walked outside and shot himself in front of the officers who were gathered in front of the property. The shooter killed his wife, her two teenage sons and a neighbor.",
#   'Title': 'Belfair, Washington',
#   'Total victims': 4},
#  {'Date': '2/25/2016',
#   'Fatalities': 4,
#   'Gender': 'Male',
#   'Injured': 14,
#   'Latitude': 38.1368,
#   'Location': 'Hesston, Kansas',
#   'Longitude': -97.4268,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 54,
#   'Summary': 'On Friday, 90 minutes after receiving a court order over domestic violence, the man returned to the factory for the shooting spree.The man who wounded three people before storming into the central Kansas the lawn mower factory where he worked and shooting 14 others, killing three of them, had just been served a protection from abuse order that likely triggered the attack. Police say they believe the man fired at random while he was returning to his workplace.',
#   'Title': 'Hesston, Kansas',
#   'Total victims': 17},
#  {'Date': '2/25/2016',
#   'Fatalities': 5,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 47.451459,
#   'Location': '42425, ',
#   'Longitude': -122.826946,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 55,
#   'Summary': 'Man killed wife, two kids, and neighbor before calling the cops to tell them he did something bad. They fired tear gas to get him outside. He came out and shot himself in the head.',
#   'Title': 'Belfair, WA Family murder-suicide',
#   'Total victims': 4},
#  {'Date': '2/23/2016',
#   'Fatalities': 5,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 33.5927,
#   'Location': 'Glendale, Arizona',
#   'Longitude': -112.163,
#   'Mental Health Issues': 'Yes',
#   'Race': 'Two or more races',
#   'S#': 56,
#   'Summary': 'Five family members are dead after the son opened fire at their house on Tuesday morning. The shooter killed his father, his mother, his 18-year-old sister, and his 6-year-old sister. Police fatally shot the  shooter after a confrontation inside the home.',
#   'Title': 'Glendale, Arizona',
#   'Total victims': 4},
#  {'Date': '2/23/2016',
#   'Fatalities': 5,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 33.448377,
#   'Location': '42423, ',
#   'Longitude': -112.074037,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 57,
#   'Summary': 'Son shot his parents and two sisters in their Phoenix home. Police arrive because the house was on fire. Police shot and killed the shooter.',
#   'Title': 'Arizona Family Murder',
#   'Total victims': 4},
#  {'Date': '2/21/2016',
#   'Fatalities': 1,
#   'Gender': 'Male',
#   'Injured': 3,
#   'Latitude': 38.77144,
#   'Location': '42421, ',
#   'Longitude': -90.370949,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 58,
#   'Summary': 'Car was fired upon from a stolen Mercedes on the interstate in Hazelwood, MO. One woman died. 3 Injured.',
#   'Title': 'Missouri Highway shooting',
#   'Total victims': 4},
#  {'Date': '2/21/2016',
#   'Fatalities': 0,
#   'Gender': 'Unknown',
#   'Injured': 5,
#   'Latitude': 29.760427,
#   'Location': '42421, ',
#   'Longitude': -95.369803,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 59,
#   'Summary': 'Group of people was fired upon by an unknown number of people in a dark SUV and a white Ford Truck. Five people, including a baby, were injured.',
#   'Title': 'Houston Drive-by',
#   'Total victims': 5},
#  {'Date': '2/20/2016',
#   'Fatalities': 2,
#   'Gender': 'Male',
#   'Injured': 3,
#   'Latitude': 34.7404,
#   'Location': 'Iuka, Mississippi',
#   'Longitude': -88.1383,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 61,
#   'Summary': 'Law enforcement officers in northeastern Mississippi stormed a house Saturday after an hours-long standoff with a gunman holed up inside, leading to a shootout that left one officer dead and three others wounded.The standoff started Friday afternoon when authorities responded to a domestic dispute call at the home near Iuka. But the man, holed up in his home with his wife and 10-year-old daughter, refused to come out, sparking the standoff with officers outside. The man suspected of firing on the officers was also killed.',
#   'Title': 'Iuka, Mississippi',
#   'Total victims': 4},
#  {'Date': '2/20/2016',
#   'Fatalities': 6,
#   'Gender': 'Male',
#   'Injured': 2,
#   'Latitude': 42.2354,
#   'Location': 'Kalamazoo, Michigan',
#   'Longitude': -85.676,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 62,
#   'Summary': 'On Saturday evening of February 20, 2016, the gunman shot eight people in three different parts of the county. For nearly five hours Saturday, the shooter drove from one target to another, gunning down victims at random. And in between the shootings, he apparently picked up passengers for Uber.',
#   'Title': 'Kalamazoo, Michigan',
#   'Total victims': 8},
#  {'Date': '2/20/2016',
#   'Fatalities': 1,
#   'Gender': 'Unknown',
#   'Injured': 3,
#   'Latitude': 27.950575,
#   'Location': '42420, ',
#   'Longitude': -82.457178,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 63,
#   'Summary': 'Argument led to gun shots in the parking lot outside of a hookah bar in Tampa, Florida',
#   'Title': 'Florida Hookah Bar Shooting',
#   'Total victims': 4},
#  {'Date': '2/20/2016',
#   'Fatalities': 6,
#   'Gender': 'Male',
#   'Injured': 2,
#   'Latitude': 42.291707,
#   'Location': '42420, ',
#   'Longitude': -85.587229,
#   'Mental Health Issues': 'No',
#   'Race': 'White American or European American',
#   'S#': 64,
#   'Summary': 'An Uber driver fired upon people in three locations over the course of about 6 hours.',
#   'Title': 'Kalamazoo Uber Driver Spree Killing',
#   'Total victims': 8},
#  {'Date': '2/19/2016',
#   'Fatalities': 2,
#   'Gender': 'Unknown',
#   'Injured': 2,
#   'Latitude': 38.104086,
#   'Location': '42419, ',
#   'Longitude': -122.256637,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 65,
#   'Summary': 'Two suspects shot at a car and killed one person outright, and the second victim died in the hospital. Two others injured. No leads on suspects.',
#   'Title': 'Vallejo, CA car shooting',
#   'Total victims': 4},
#  {'Date': '2/9/2016',
#   'Fatalities': 0,
#   'Gender': 'Male',
#   'Injured': 3,
#   'Latitude': 43.201126,
#   'Location': '42409, ',
#   'Longitude': -86.238946,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 66,
#   'Summary': "Shooter was a part of a fight outside of a high school gym. He fired at a crowd, injuring three. He fled the scene and was confronted by a police officer. When he wouldn't drop his weapon, the police officer shot and injured him.",
#   'Title': 'Michigan school shooting',
#   'Total victims': 3},
#  {'Date': '2/7/2016',
#   'Fatalities': 2,
#   'Gender': 'Male',
#   'Injured': 10,
#   'Latitude': 28.4541,
#   'Location': 'Orlando, Florida',
#   'Longitude': -81.4646,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Some other race',
#   'S#': 67,
#   'Summary': 'Two people were killed and several others were hurt in a mass shooting inside an Orlando nightclub early Sunday morning.',
#   'Title': 'Orlando, Florida',
#   'Total victims': 12},
#  {'Date': '2/7/2016',
#   'Fatalities': 1,
#   'Gender': 'Unknown',
#   'Injured': 7,
#   'Latitude': 43.16103,
#   'Location': '42407, ',
#   'Longitude': -77.610922,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 68,
#   'Summary': 'Two groups of people fired at each other after a fight broke out outside of the Mexican Village Nightclub in Rochester, NY',
#   'Title': 'Nightclub fight turns into shootout',
#   'Total victims': 8},
#  {'Date': '2/6/2016',
#   'Fatalities': 2,
#   'Gender': 'Unknown',
#   'Injured': 6,
#   'Latitude': 27.950575,
#   'Location': '42406, ',
#   'Longitude': -82.457178,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 69,
#   'Summary': 'Fighting broke out in a strip club when an unknown shooter starting firing. One person died on the scene, and one died later. Six were injured.',
#   'Title': 'Tampa, FL Strip club shooting',
#   'Total victims': 8},
#  {'Date': '2/6/2016',
#   'Fatalities': 1,
#   'Gender': 'Unknown',
#   'Injured': 3,
#   'Latitude': 34.052234,
#   'Location': '42406, ',
#   'Longitude': -118.243685,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 70,
#   'Summary': 'Police were called to a street to investigate an assault case. One hispanic man lay dead on the street. Two other adult males, and a young female were injured.',
#   'Title': 'Los Angeles, CA street shooting',
#   'Total victims': 4},
#  {'Date': '2/6/2016',
#   'Fatalities': 4,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 29.209684,
#   'Location': '42406, ',
#   'Longitude': -99.786168,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 71,
#   'Summary': '19-year-old male kills his mother and two neighbors before killing himself. Motive is unclear.',
#   'Title': 'Texas teen commits family murder suicide',
#   'Total victims': 3},
#  {'Date': '1/31/2016',
#   'Fatalities': 0,
#   'Gender': 'Male',
#   'Injured': 3,
#   'Latitude': 29.951066,
#   'Location': '42400, ',
#   'Longitude': -90.071532,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 72,
#   'Summary': 'Altercation broke out at a gas station in New Orleans, when the shooter shot and injured 3 people. One of the victims returned fire and injured the instigator.',
#   'Title': 'New Orleans gas station shoot-out',
#   'Total victims': 3},
#  {'Date': '1/30/2016',
#   'Fatalities': 3,
#   'Gender': 'Male',
#   'Injured': 5,
#   'Latitude': 33.538652,
#   'Location': '42399, ',
#   'Longitude': -112.185987,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 73,
#   'Summary': 'Altercation broke out at a house party. A group of five hispanics were asked to leave. They got in a car, and as they drove away, opened fire on the house.',
#   'Title': 'Glendale, AZ House Party shooting',
#   'Total victims': 8},
#  {'Date': '1/29/2016',
#   'Fatalities': 2,
#   'Gender': 'Male',
#   'Injured': 2,
#   'Latitude': 38.044556,
#   'Location': '42398, ',
#   'Longitude': -77.286488,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 74,
#   'Summary': '42-year-old husband murders wife, shoots two young family members, then shoots himself in the head.',
#   'Title': 'Caroline County, VA Family Murder Suicide',
#   'Total victims': 3},
#  {'Date': '1/27/2016',
#   'Fatalities': 6,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 36.7921,
#   'Location': 'Chesapeake, Virginia',
#   'Longitude': -76.3293,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 75,
#   'Summary': 'A Virginia man shot his brother dead in their family home, then killed four other relatives in a nearby house before turning the gun on himself Wednesday. He killed his brother in their house around 3:35 p.m. He then went to the house belonging to his grandmother and murdered more relatives ? father, mother, sister, and an unidentified female.',
#   'Title': 'Chesapeake, Virginia',
#   'Total victims': 5},
#  {'Date': '1/27/2016',
#   'Fatalities': 6,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 36.768209,
#   'Location': '42396, ',
#   'Longitude': -76.287493,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 76,
#   'Summary': '26-year-old killed his Mother, Father, Grandmother, brother, and sister before killing himself in the home of his Grandmother.',
#   'Title': 'Chesapeake, VA Family Murder Suicide',
#   'Total victims': 5},
#  {'Date': '1/25/2016',
#   'Fatalities': 1,
#   'Gender': 'Male',
#   'Injured': 4,
#   'Latitude': 33.782519,
#   'Location': '42394, ',
#   'Longitude': -117.228648,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 77,
#   'Summary': 'Very little is known about the case. Cops were called to a Mexican restaurant. 1 person was pronounced dead at the scene. 4 others were taken to a hospital.',
#   'Title': 'Perris, CA Mexican restaurant shooting',
#   'Total victims': 5},
#  {'Date': '1/23/2016',
#   'Fatalities': 3,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 30.754181,
#   'Location': '42392, ',
#   'Longitude': -86.572799,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 78,
#   'Summary': "A young man shot his mother, step-father, and his ex-girlfriend's boyfriend",
#   'Title': 'Florida family murder',
#   'Total victims': 3},
#  {'Date': '1/23/2016',
#   'Fatalities': 2,
#   'Gender': 'Unknown',
#   'Injured': 2,
#   'Latitude': 34.052234,
#   'Location': '42392, ',
#   'Longitude': -118.243685,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 79,
#   'Summary': 'Group of people was standing outside of a Liquor store on Avalon boulevard in South Los Angeles. A car drove by and fired an AK-47, killing 1 and wounding 3.',
#   'Title': 'Los Angeles Drive-by',
#   'Total victims': 4},
#  {'Date': '1/17/2016',
#   'Fatalities': 1,
#   'Gender': 'Male',
#   'Injured': 3,
#   'Latitude': 37.40264,
#   'Location': '42386, ',
#   'Longitude': -76.458559,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 80,
#   'Summary': 'A young woman threw a house party for her birthday. It got very crowded. The shooter came and shot four people, killing one. There is some disagreement about his relation to the rest of the people at the party',
#   'Title': 'Gloucester County, VA, House Party',
#   'Total victims': 4},
#  {'Date': '1/11/2016',
#   'Fatalities': 1,
#   'Gender': 'Male',
#   'Injured': 4,
#   'Latitude': 39.739072,
#   'Location': '42380, ',
#   'Longitude': -75.539788,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 81,
#   'Summary': 'Two men forcefully entered a house, and started shooting the people inside. One of the robbers was killed. Four other people injured.',
#   'Title': 'Wilmington, DE robbery',
#   'Total victims': 5},
#  {'Date': '1/7/2016',
#   'Fatalities': 1,
#   'Gender': 'Unknown',
#   'Injured': 3,
#   'Latitude': 35.149534,
#   'Location': '42376, ',
#   'Longitude': -90.04898,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 82,
#   'Summary': 'A woman flagged down a car to help her with her car troubles at the side of the road. An 18-year-old got out to help. The two suspects got out of another car and fired on the scene.',
#   'Title': 'Roadside in Memphis, Tennessee',
#   'Total victims': 4},
#  {'Date': '1/6/2016',
#   'Fatalities': 3,
#   'Gender': 'Male',
#   'Injured': 1,
#   'Latitude': 28.039465,
#   'Location': '42375, ',
#   'Longitude': -81.949804,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 83,
#   'Summary': 'Two men arrived at the house of a drug dealer and killed three people and critically injured one more.',
#   'Title': 'Residence in Lakeland, Florida',
#   'Total victims': 4},
#  {'Date': '12/6/2015',
#   'Fatalities': 2,
#   'Gender': 'Male',
#   'Injured': 3,
#   'Latitude': 41.3138,
#   'Location': 'Omaha, Nebraska',
#   'Longitude': -96.0814,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 84,
#   'Summary': 'A woman and her two year old daughter were shot and killed Sunday. Three other women are still fighting for their lives following the shooting.  The suspect turned himself into police on Tuesday morning.',
#   'Title': 'Omaha, Nebraska',
#   'Total victims': 5},
#  {'Date': '12/2/2015',
#   'Fatalities': 16,
#   'Gender': 'Male/Female',
#   'Injured': 21,
#   'Latitude': 34.13973446,
#   'Location': 'San Bernardino, California',
#   'Longitude': -117.2942444,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Asian American',
#   'S#': 86,
#   'Summary': 'On Wednesday of December 2, 2015, two gunmen entered a conference room on the Inland Regional Center property, killing 14 people, and injuring 21 people. The facility was rented by the San Bernardino County Department of Public Health for a holiday party. The shooter was at the party but left abruptly before the shooting. He seemed angry, witnesses told police. He returned and along with his wife, he went into the building and began firing. The man was an inspector with the county health department that hosted the party. ',
#   'Title': 'San Bernardino, California',
#   'Total victims': 35},
#  {'Date': '11/27/2015',
#   'Fatalities': 3,
#   'Gender': 'Male',
#   'Injured': 9,
#   'Latitude': 38.86730659,
#   'Location': 'Colorado Springs, Colorado',
#   'Longitude': -104.7572279,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 88,
#   'Summary': 'On Friday of November 27, 2015, the shooter opened fire inside a Planned Parenthood clinic in Colorado Springs. Three people were killed and nine others were hurt. The shooter surrendered to officers after a five-hour ordeal Friday in which he fired randomly at people in the clinic and roamed the halls shooting through walls with an assault-style rifle.',
#   'Title': 'Colorado Springs, Colorado',
#   'Total victims': 12},
#  {'Date': '11/23/2015',
#   'Fatalities': 4,
#   'Gender': 'Male',
#   'Injured': 1,
#   'Latitude': 39.98861445,
#   'Location': 'Columbus, Ohio',
#   'Longitude': -82.98904135,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 89,
#   'Summary': 'On Monday of November 23, 2015, three of four members of a family were shot and killed and a 12-year-old girl wounded at their home. The suspect died after being shot by police. The shooter was a once friendly neighbor of the victims.',
#   'Title': 'Columbus, Ohio',
#   'Total victims': 4},
#  {'Date': '11/23/2015',
#   'Fatalities': 0,
#   'Gender': 'Male',
#   'Injured': 5,
#   'Latitude': 44.96358722,
#   'Location': 'Minneapolis, Minnesota',
#   'Longitude': -93.26783687,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 90,
#   'Summary': 'Five protesters were shot late Monday night near the Black Lives Matter encampment. A group of white supremacists showed up at the protest, and when about a dozen protesters attempted to herd the group away from the area, they opened fire on the protesters. Protesters have been camping out in front of the 4th Precinct since Nov. 15',
#   'Title': 'Minneapolis, Minnesota',
#   'Total victims': 5},
#  {'Date': '11/15/2015',
#   'Fatalities': 6,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 31.8076,
#   'Location': 'Tennessee Colony, Texas',
#   'Longitude': -95.8069,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 91,
#   'Summary': "On Sunday of November 15, 2015, six people are dead after a weekend homicide at a private campsite. The bodies of a man and woman were found in a travel trailer. The bodies of four males, who were initially considered missing, were later recovered about 1:15 p.m. Monday in a pond on the suspect's residence. ",
#   'Title': 'Tennessee Colony, Texas',
#   'Total victims': 6},
#  {'Date': '11/13/2015',
#   'Fatalities': 4,
#   'Gender': 'Male',
#   'Injured': 1,
#   'Latitude': 30.33216122,
#   'Location': 'Jacksonville, Florida',
#   'Longitude': -81.67576993,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 92,
#   'Summary': "On Friday of November 13, 2015,The former military member walked into his Northside, Florida, home and shot his girlfriend, their twin babies, and girlfriend's father before shooting himself. The shooter had a history of domestic violence.",
#   'Title': 'Jacksonville, Florida',
#   'Total victims': 4},
#  {'Date': '11/7/2015',
#   'Fatalities': 1,
#   'Gender': 'Male',
#   'Injured': 2,
#   'Latitude': 31.21094544,
#   'Location': 'Waycross, Georgia',
#   'Longitude': -82.35793452,
#   'Mental Health Issues': 'Yes',
#   'Race': 'Black American or African American',
#   'S#': 93,
#   'Summary': 'On Saturday of November 7, 2015,a pregnant mother of two was killed in a violent rampage early Saturday along with her unborn child. Both of her toddlers were also shot. The shooter is the father of one of the small children.',
#   'Title': 'Waycross, GA',
#   'Total victims': 3},
#  {'Date': '11/4/2015',
#   'Fatalities': 4,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 44.54994725,
#   'Location': 'Oakland, Maine',
#   'Longitude': -69.70782299,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Unknown',
#   'S#': 94,
#   'Summary': "A gunman shot his girlfriend,  his girlfriend's sister and her boyfriend to death in a Central Maine apartment building, leaving a young girl unharmed on the first floor before turning the weapon on himself. They all shared the brown clapboard home, which was divided into two apartments. The gunman and his girlfriend lived in the upstairs room of the apartment while the two other victims (his girlfriend's sister and her boyfriend) lived in the downstairs with their 3 year old daughter. All three victims were found on first floor.",
#   'Title': 'Oakland, Maine',
#   'Total victims': 3},
#  {'Date': '10/31/2015',
#   'Fatalities': 4,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 38.86730659,
#   'Location': 'Colorado Springs, Colorado',
#   'Longitude': -104.7572279,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 96,
#   'Summary': 'In the morning of October 31, 2015, three victims were shot and killed on the streets and sidewalks of the neighborhood.The gunman died in a shootout with police. A witness described he was walking in the street with two guns, walking calmly. The shooter killed a bicyclist and two women at a nearby location.',
#   'Title': 'Colorado Springs',
#   'Total victims': 3},
#  {'Date': '10/21/2015',
#   'Fatalities': 2,
#   'Gender': 'Male',
#   'Injured': 1,
#   'Latitude': 39.253268,
#   'Location': 'Colerain Township, Ohio',
#   'Longitude': -84.599655,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 97,
#   'Summary': 'A man killed his two teenage sisters and injured another teen in Colerain Township, Ohio, in the early hours of Tuesday, Oct. 21, 2015.',
#   'Title': 'Colerain Township, Ohio',
#   'Total victims': 3},
#  {'Date': '10/9/2015',
#   'Fatalities': 1,
#   'Gender': 'Male',
#   'Injured': 3,
#   'Latitude': 35.1725658,
#   'Location': 'Flagstaff, Arizona',
#   'Longitude': -111.6585435,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 98,
#   'Summary': "On Friday of October 9, 2015, one person is dead and three are wounded after an early morning shooting on Northern Arizona University's campus. An overnight confrontation between two groups of students escalated into gunfire. The shooter is a freshman of Northern Arizona University.",
#   'Title': 'Northern Arizona University at Flagstaff Campus',
#   'Total victims': 4},
#  {'Date': '10/1/2015',
#   'Fatalities': 10,
#   'Gender': 'Male',
#   'Injured': 7,
#   'Latitude': 43.22205555,
#   'Location': 'Roseburg, Oregon',
#   'Longitude': -123.3522367,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Two or more races',
#   'S#': 100,
#   'Summary': 'On Monday of October 1, 2015, a gunman opened fire at a rural Oregon community college Thursday. 9 people were dead and seven wounded, three critically, before dying in a shootout with police. First, a shot came through the window and hit the teacher in the head  in a freshman writing class. The gunman then entered the Snyder Hall classroom and told people to get on the floor. He told people to stand up and state their religion before opening fire.',
#   'Title': 'Umpqua Community College',
#   'Total victims': 16},
#  {'Date': '10/1/2015',
#   'Fatalities': 3,
#   'Gender': 'Male',
#   'Injured': 1,
#   'Latitude': 29.03270634,
#   'Location': 'Inglis, Florida',
#   'Longitude': -82.65919302,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 101,
#   'Summary': "A man 57-year-old man shot and killed his wife, injured her boyfriend, and killed a Good Samaritan 68-year-old man as he rushed to protect children who were playing near the town hall before taking his life. The shooter's couple had been married for 35 years when they separated, and the shooter's wife had left her husband for her new boyfriend.",
#   'Title': 'Inglis, Florida',
#   'Total victims': 3},
#  {'Date': '9/27/2015',
#   'Fatalities': 0,
#   'Gender': 'Male',
#   'Injured': 10,
#   'Latitude': 33.02912644,
#   'Location': 'Greenville, Georgia',
#   'Longitude': -84.7143335,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 102,
#   'Summary': 'A shooting at a club in Meriwether Co. early Sunday injured 10 people after witnesses say gun fire was exchanged that stemmed from alleged illegal gambling.',
#   'Title': "Hill Haven Event Center (Formerly Club CJ's)",
#   'Total victims': 10},
#  {'Date': '9/17/2015',
#   'Fatalities': 6,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 43.38682722,
#   'Location': 'Platte, South Dakota',
#   'Longitude': -98.84357239,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 103,
#   'Summary': "The six members of a South Dakota family found dead in the ruins of their burned home were fatally shot, with one death believed to be a suicide. All six members of the shooter's family died of shotgun wounds.",
#   'Title': 'Platte, South Dakota',
#   'Total victims': 5},
#  {'Date': '9/10/2015',
#   'Fatalities': 5,
#   'Gender': 'Male',
#   'Injured': 0,
#   'Latitude': 47.69618799,
#   'Location': 'Clearbrook (Greenwood), Minnesota',
#   'Longitude': -95.42844094,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 104,
#   'Summary': 'Five family members - two adults and three children - were found dead in a home on Thursday, September 10 in an apparent murder-suicide. The shooter, a nurse, founded the website AllNurses.com, which provides information and resources for and about the nursing profession.',
#   'Title': 'Clearbrook (Greenwood), Minnesota',
#   'Total victims': 4},
#  {'Date': '8/29/2015',
#   'Fatalities': 3,
#   'Gender': 'Male',
#   'Injured': 1,
#   'Latitude': 36.55605824,
#   'Location': 'Bristol, Tennessee',
#   'Longitude': -82.21429551,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 105,
#   'Summary': 'The shooter shot and killed his mother, stepfather, and grandmother in a matter of seconds on Saturday night.',
#   'Title': 'Bristol, Tennessee',
#   'Total victims': 4},
#  {'Date': '8/26/2015',
#   'Fatalities': 3,
#   'Gender': 'Male',
#   'Injured': 1,
#   'Latitude': 37.27823366,
#   'Location': 'Roanoke, Virginia',
#   'Longitude': -79.95816104,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 106,
#   'Summary': 'Wednesday morning on August 26, 2015, a former employee of a Virginia TV news station waited until two of his former colleagues were live on air presenting a local tourism story at an outdoor shopping mall, then filmed himself raising a gun and shooting them both dead. A third victim survived the attack. He uploaded the videos to Twitter before committing suicide.',
#   'Title': 'Virginia WDBJ live TV interview shooting',
#   'Total victims': 3},
#  {'Date': '8/19/2015',
#   'Fatalities': 3,
#   'Gender': 'Male',
#   'Injured': 4,
#   'Latitude': 43.1696837,
#   'Location': 'Rochester, New York',
#   'Longitude': -77.614337,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 107,
# ...
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 372,
#   'Summary': 'On April 23, 1987, a 59-year-old retired librarian in Palm Bay, Florida began a shooting spree in his neighborhood, where he shot and injured several of his neighbors. He continued the shooting at two local shopping centers, killing a total of four civilians and two police officers, and injuring nine others.',
#   'Title': 'Palm Bay Shopping Centers',
#   'Total victims': 20},
#  {'Date': '12/4/1986',
#   'Fatalities': 1,
#   'Gender': 'Male',
#   'Injured': 3,
#   'Latitude': 47.03740653,
#   'Location': 'Lewistown, Montana',
#   'Longitude': -109.4844918,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 373,
#   'Summary': 'On December 4, 1986, a 14-year-old student at Fergus County High School in Lewistown, Montana, disgruntled with his grades, fatally shot a teacher and wounded a vice principal and two students as he fled. He was arrested at his home an hour later.',
#   'Title': 'Fergus County High School',
#   'Total victims': 4},
#  {'Date': '8/20/1986',
#   'Fatalities': 15,
#   'Gender': 'Male',
#   'Injured': 6,
#   'Latitude': 35.6672015,
#   'Location': 'Edmond, Oklahoma',
#   'Longitude': -97.42937037,
#   'Mental Health Issues': 'Unclear ',
#   'Race': 'white',
#   'S#': 374,
#   'Summary': 'Postal worker Patrick Sherrill, 44, opened fire at a post office before committing suicide.',
#   'Title': 'United States Postal Service shooting',
#   'Total victims': 21},
#  {'Date': '8/20/1986',
#   'Fatalities': 15,
#   'Gender': 'Male',
#   'Injured': 6,
#   'Latitude': 35.66889223,
#   'Location': 'Edmond, Oklahoma',
#   'Longitude': -97.41438792,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 375,
#   'Summary': 'On August 20, 1986, a 44-year-old postal worker in Edmond, Oklahoma opened fire on his supervisors and coworkers at the post office in which he worked. He killed fourteen postal employees and wounded six others before committing suicide.',
#   'Title': 'Post office in Edmond, Oklahoma',
#   'Total victims': 20},
#  {'Date': '8/12/1986',
#   'Fatalities': 1,
#   'Gender': 'Male',
#   'Injured': 4,
#   'Latitude': 40.679276,
#   'Location': 'Brooklyn, New York',
#   'Longitude': -73.939513,
#   'Mental Health Issues': 'Yes',
#   'Race': 'Black American or African American',
#   'S#': 376,
#   'Summary': 'On August 12, 1986, a 29-year civil technology student  at New York Technical College in Brooklyn went to the school thinking his supervisor was the reason he had not received his financial aid. He killed the supervisor and wounded four other people. He was later arrested by the police.',
#   'Title': 'New York Technical College',
#   'Total victims': 5},
#  {'Date': '3/6/1985',
#   'Fatalities': 2,
#   'Gender': 'Male',
#   'Injured': 1,
#   'Latitude': 33.7629969,
#   'Location': 'Atlanta, Georgia',
#   'Longitude': -84.4231328,
#   'Mental Health Issues': 'Yes',
#   'Race': 'Black American or African American',
#   'S#': 377,
#   'Summary': 'On March 6, 1985, a 30-year-old employee at the Atlanta Post Office, opened fire in the mail sorting area killing two of his coworkers and wounding a third one before he was subdue by other postal workers.',
#   'Title': 'Atlanta Post Office',
#   'Total victims': 3},
#  {'Date': '1/21/1985',
#   'Fatalities': 1,
#   'Gender': 'Male',
#   'Injured': 3,
#   'Latitude': 37.67129418,
#   'Location': 'Goddard, Kansas',
#   'Longitude': -97.55070476,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 378,
#   'Summary': 'On January 21, 1985, a 14-year-old student entered Goddard Junior High School in Goddard, Kansas. The student killed the principal and injured two teachers and another student. He was arrested 90 minutes later by a policeman in a field just south of Goddard.',
#   'Title': 'Goddard Junior High School',
#   'Total victims': 4},
#  {'Date': '7/18/1984',
#   'Fatalities': 22,
#   'Gender': 'Male',
#   'Injured': 19,
#   'Latitude': 32.5520013,
#   'Location': 'San Ysidro, California',
#   'Longitude': -117.0430813,
#   'Mental Health Issues': 'Yes',
#   'Race': 'white',
#   'S#': 379,
#   'Summary': "James Oliver Huberty, 41, opened fire in a McDonald's restaurant before he was shot dead by a police officer.",
#   'Title': "San Ysidro McDonald's massacre",
#   'Total victims': 41},
#  {'Date': '7/18/1984',
#   'Fatalities': 22,
#   'Gender': 'Male',
#   'Injured': 19,
#   'Latitude': 32.555556,
#   'Location': 'San Ysidro, California',
#   'Longitude': -117.047656,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 380,
#   'Summary': "On July 18, 1984, a 41-year-old unemployed man, walked into a McDonald's restaurant in San Ysidro, California, killing twenty-one people and injuring nineteen others. The shooter was killed at the scene by a SWAT team sniper perched on the roof next door.",
#   'Title': "McDonald's restaurant in San Ysidro",
#   'Total victims': 40},
#  {'Date': '6/29/1984',
#   'Fatalities': 6,
#   'Gender': 'Male',
#   'Injured': 1,
#   'Latitude': 32.7801052,
#   'Location': 'Dallas, Texas',
#   'Longitude': -96.8000082,
#   'Mental Health Issues': 'Yes',
#   'Race': 'white',
#   'S#': 381,
#   'Summary': 'Abdelkrim Belachheb, 39, opened fire at an upscale nightclub after a woman rejected his advances. He was later arrested.',
#   'Title': 'Dallas nightclub shooting',
#   'Total victims': 7},
#  {'Date': '6/29/1984',
#   'Fatalities': 6,
#   'Gender': 'Male',
#   'Injured': 1,
#   'Latitude': 32.79480596,
#   'Location': 'Dallas, Texas',
#   'Longitude': -96.76631094,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 382,
#   'Summary': "On June 29, 1984, a 39-year-old man who was rejected by a dance partner at Ianni's Dance Club in Dallas, Texas, left the club and returned with a semiautomatic pistol killing the woman and five other patrons and seriously wounded a seventh person. ",
#   'Title': "Ianni's Club in Dallas",
#   'Total victims': 7},
#  {'Date': '2/24/1984',
#   'Fatalities': 3,
#   'Gender': 'Male',
#   'Injured': 12,
#   'Latitude': 34.17622092,
#   'Location': 'Los Angeles, California',
#   'Longitude': -118.5399542,
#   'Mental Health Issues': 'Yes',
#   'Race': 'Black American or African American',
#   'S#': 383,
#   'Summary': 'On February 24, a 28-year-old man began shooting at children and staff leaving 49th Street Elementary School in South Central Los Angeles in California. The gunman positioned himself in a room on the second story of his home and killed two people and wounded twelve others.',
#   'Title': '49th Street Elementary School',
#   'Total victims': 14},
#  {'Date': '8/19/1983',
#   'Fatalities': 1,
#   'Gender': 'Male',
#   'Injured': 3,
#   'Latitude': 33.83272887,
#   'Location': 'Johnston, South Carolina',
#   'Longitude': -81.8051584,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 384,
#   'Summary': 'On August 19, 1983, a 55-year-old former postal worker went into the Johnston Post Office in South Carolina three months after he had resigned. He killed the local postmaster and wounded three others. It was the last day at work for the postmaster.',
#   'Title': 'Johnston Post Office',
#   'Total victims': 4},
#  {'Date': '2/18/1983',
#   'Fatalities': 13,
#   'Gender': 'Male',
#   'Injured': 1,
#   'Latitude': 47.62199575,
#   'Location': 'Seattle, Washington',
#   'Longitude': -122.323646,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Asian American',
#   'S#': 385,
#   'Summary': 'On February 18, 1983, three man between the ages of 22 and 24 entered the Wah Mee gambling club in Seattle, Washington, shooting fourteen people. Thirteen victims lost their lives, but one survived to testify.',
#   'Title': 'Wah Mee Club in Seattle',
#   'Total victims': 14},
#  {'Date': '8/20/1982',
#   'Fatalities': 8,
#   'Gender': 'Male',
#   'Injured': 3,
#   'Latitude': 25.796491,
#   'Location': 'Miami, Florida',
#   'Longitude': -80.226683,
#   'Mental Health Issues': 'Yes',
#   'Race': 'white',
#   'S#': 386,
#   'Summary': 'Junior high school teacher Carl Robert Brown, 51, opened fire inside a welding shop and was later shot dead by a witness as he fled the scene.',
#   'Title': 'Welding shop shooting',
#   'Total victims': 11},
#  {'Date': '8/20/1982',
#   'Fatalities': 9,
#   'Gender': 'Male',
#   'Injured': 3,
#   'Latitude': 25.79653943,
#   'Location': 'Miami, Florida',
#   'Longitude': -80.20840397,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 387,
#   'Summary': 'On August 20, 1982, a 51-year-old teacher on psychiatric leave opened fire inside a welding shop in Miami, Florida killing eight employees and wounding another three. The shooter was later shot and run down by two witnesses while he was cycling away from the crime scene.',
#   'Title': 'Welding shop in Miami',
#   'Total victims': 11},
#  {'Date': '3/19/1982',
#   'Fatalities': 1,
#   'Gender': 'Male',
#   'Injured': 2,
#   'Latitude': 36.18931923,
#   'Location': 'Las Vegas, Nevada',
#   'Longitude': -115.3264875,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 388,
#   'Summary': 'On March 19, 1982, a 17-year-old student walked into Valley High School in Las Vegas, Nevada. The shooter shot and killed a teacher and injured two students.',
#   'Title': 'Valley High School',
#   'Total victims': 3},
#  {'Date': '10/6/1979',
#   'Fatalities': 2,
#   'Gender': 'Male',
#   'Injured': 5,
#   'Latitude': 34.05098834,
#   'Location': 'Columbia, South Carolina',
#   'Longitude': -80.82077527,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'Black American or African American',
#   'S#': 389,
#   'Summary': 'On October 6, 1979, a 19-year-old student at University of South Carolina opened fire at a homecoming weekend fraternity party, killing two students and wounding five others.',
#   'Title': 'University of South Carolina',
#   'Total victims': 7},
#  {'Date': '1/29/1979',
#   'Fatalities': 2,
#   'Gender': 'Female',
#   'Injured': 9,
#   'Latitude': 32.86357277,
#   'Location': 'San Diego, California',
#   'Longitude': -117.1281628,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 390,
#   'Summary': 'On January 29, 1979, a 16-year-old opened fire at children waiting to enter Grover Cleveland Elementary School. The shooter put herself by a window in her home and began shooting across the street while the children were waiting outside for the principal to open the gate.  The principal and a custodian were killed and eight children and a police officer were injured.',
#   'Title': 'Grover Cleveland Elementary School',
#   'Total victims': 11},
#  {'Date': '7/12/1976',
#   'Fatalities': 7,
#   'Gender': 'Male',
#   'Injured': 2,
#   'Latitude': 33.88404244,
#   'Location': 'Fullerton, California',
#   'Longitude': -117.92785,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 391,
#   'Summary': "On July 12, 1976, a 37-year-old custodian at California State University in Fullerton open fired in the library's first-floor lobby and at the building's Instructional Media Center killing seven people and wounding two others. ",
#   'Title': 'Cal State Fullerton',
#   'Total victims': 9},
#  {'Date': '2/19/1976',
#   'Fatalities': 1,
#   'Gender': 'Male',
#   'Injured': 7,
#   'Latitude': 34.17622092,
#   'Location': 'Los Angeles, California',
#   'Longitude': -118.5399542,
#   'Mental Health Issues': 'Unknown',
#   'Race': 'White American or European American',
#   'S#': 392,
#   'Summary': 'On February 19, 1976, a 18-year-old student at a Los Angeles computer school opened fire during a test at his fellow students with a shotgun, killing one student and wounding several others. When trying to escape, he was apprehended by a security guard who exchanged fire with the shooter, leaving him critically wounded. The security guard was injured during the exchange.',
#   'Title': 'Los Angeles Computer Learning Center',
#   'Total victims': 8},
#  {'Date': '12/30/1974',
#   'Fatalities': 3,
#   'Gender': 'Male',
#   'Injured': 7,
#   'Latitude': 42.08185369,
#   'Location': 'Olean, New York',
#   'Longitude': -78.43213922,
#   'Mental Health Issues': 'No',
#   'Race': 'White American or European American',
#   'S#': 393,
#   'Summary': "On December 30, 1974, a 17-year-old honor student and member of the school's rifle team, entered Olean High School, looked himself in a room on the school's third floor, where he shot a custodian inside the building and nine people on the streets below. Following the shooting, police had found homemade propane bombs in Barbaro's bedroom, as well as bomb recipes and a journal that detailed his plans of the shooting.",
#   'Title': 'Olean High School',
#   'Total victims': 10},
#  {'Date': '1/17/1974',
#   'Fatalities': 1,
#   'Gender': 'Male',
#   'Injured': 3,
#   'Latitude': 41.83928045,
#   'Location': 'Chicago, Illinois',
#   'Longitude': -87.68818145,
#   'Mental Health Issues': 'Yes',
#   'Race': 'Unknown',
#   'S#': 394,
#   'Summary': 'On January 17, 1974, a 14-year-old student entered Clara Barton Elementary School in Chicago, Illinois and killed the principal and wounded three others before he was seized by a teacher when both his guns jammed. Apparently, the student was angry at the fact that he had been expelled from the school and transferred to a social adjustment center earlier that week.',
#   'Title': 'Clara Barton Elementary School',
#   'Total victims': 4},
#  {'Date': '12/31/1972',
#   'Fatalities': 10,
#   'Gender': 'Male',
#   'Injured': 13,
#   'Latitude': 30.0687242,
#   'Location': 'New Orleans, Louisiana',
#   'Longitude': -89.93147412,
#   'Mental Health Issues': 'Yes',
#   'Race': 'Black American or African American',
#   'S#': 395,
#   'Summary': "On New Year's Eve in 1972, a 23-year-old ex-Navy dental technician went to the central lockup New Orleans Police Department and shot four policeman that day.  Seven days later on January 7, 1973, the shooter shot a grocer and entered the Downtown Howard Johnson Hotel where he shot seventeen people before killed him at the top of the hotel roof.",
#   'Title': 'New Orleans Police Shootings',
#   'Total victims': 22},
#  {'Date': '11/11/1971',
#   'Fatalities': 2,
#   'Gender': 'Male',
#   'Injured': 4,
#   'Latitude': 47.67367375,
#   'Location': 'Spokane, Washington',
#   'Longitude': -117.4159843,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 396,
#   'Summary': 'On November 11, 1971, a former MIT student entered St. Aloysius Roman Catholic Church on the Gonzaga University campus. The shooter killed the caretaker and wounded four more people before he was killed by police.',
#   'Title': 'St. Aloysius Church',
#   'Total victims': 5},
#  {'Date': '11/12/1966',
#   'Fatalities': 5,
#   'Gender': 'Male',
#   'Injured': 1,
#   'Latitude': 33.42268696,
#   'Location': 'Mesa, Arizona',
#   'Longitude': -111.8163202,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 397,
#   'Summary': "On November 12, 1966, an 18-year-old high school student entered the Rose-Mar College of Beauty in Mesa, Arizona, ordering his victims to lay on the ground in a circle. The gunman shot and killed four women and a child and injured another woman and an infant. He considered a few sites, like his school, where he thought of wiping out the teachers. Finally, he settled on the Rose-Mar College of Beauty, where he thought he'd get a nice large group of victims.",
#   'Title': 'Rose-Mar College of Beauty',
#   'Total victims': 6},
#  {'Date': '8/1/1966',
#   'Fatalities': 17,
#   'Gender': 'Male',
#   'Injured': 32,
#   'Latitude': 30.1988873,
#   'Location': 'Austin, Texas',
#   'Longitude': -97.84415949,
#   'Mental Health Issues': 'Yes',
#   'Race': 'White American or European American',
#   'S#': 398,
#   'Summary': 'On August 1, 1966, a 25-year-old engineering student at the University of Texas in Austin killed sixteen people and wounded thirty-two others in and around the Tower of the University of Texas. Prior to commencing the mass shootings at the University, the student and former U.S. Marine, had murdered both his wife and mother in Austin, Texas.',
#   'Title': 'University of Texas at Austin',
#   'Total victims': 48}]

# %%
from flair.data import Sentence
from flair.models import SequenceTagger

# load tagger
tagger = SequenceTagger.load("flair/ner-english-large")

# print predicted NER spans
print('The following NER tags are found:')

# iterate over entities and print
count = 0
for s in df['Summary']:
    # make example sentence
    sentence = Sentence(s)
    # predict NER tags
    tagger.predict(sentence)
    # get the results
    results = sentence.to_dict(tag_type='ner')["entities"]
    temp = []
    for r in results:
        temp.append({"text": r["text"], "labels": r["labels"][0].value})
    print(temp)
    output[count]["NER"] = temp
    count += 1
# Out:
# 2021-11-22 18:12:32,439 loading file /root/.flair/models/ner-english-large/07301f59bb8cb113803be316267f06ddf9243cdbba92a4c8067ef92442d2c574.554244d3476d97501a766a98078421817b14654496b86f2f7bd139dc502a4f29
# The following NER tags are found:
# []
# []
# []
# []
# []
# []
# [{'text': 'Alabama', 'labels': 'LOC'}]
# []
# []
# []
# [{'text': 'South Shore', 'labels': 'LOC'}, {'text': 'Chicago', 'labels': 'LOC'}]
# []
# [{'text': 'Virginia', 'labels': 'LOC'}, {'text': 'Greyhound', 'labels': 'LOC'}]
# []
# []
# [{'text': 'Alabama', 'labels': 'LOC'}]
# []
# [{'text': 'Sherman', 'labels': 'LOC'}, {'text': 'TX', 'labels': 'LOC'}]
# [{'text': 'Iraq', 'labels': 'LOC'}]
# [{'text': 'Kentucky', 'labels': 'LOC'}]
# [{'text': 'Spring Break', 'labels': 'MISC'}]
# [{'text': 'Wetumpka', 'labels': 'LOC'}, {'text': 'Alabama', 'labels': 'LOC'}]
# []
# []
# []
# []
# [{'text': 'Trenton', 'labels': 'LOC'}, {'text': 'NJ', 'labels': 'LOC'}, {'text': 'Acura', 'labels': 'ORG'}]
# []
# []
# []
# [{'text': 'Kansas City', 'labels': 'LOC'}, {'text': 'Kansas', 'labels': 'LOC'}, {'text': 'Missouri', 'labels': 'LOC'}]
# [{'text': 'MLK boulevard', 'labels': 'LOC'}, {'text': 'Lafayette', 'labels': 'LOC'}, {'text': 'LA', 'labels': 'LOC'}, {'text': 'Ford', 'labels': 'ORG'}]
# []
# [{'text': 'Chelsea', 'labels': 'LOC'}]
# [{'text': 'Chelsea', 'labels': 'LOC'}, {'text': 'MA', 'labels': 'LOC'}]
# []
# []
# []
# []
# []
# [{'text': "Mason County Sheriff's Office", 'labels': 'ORG'}]
# [{'text': 'Kansas', 'labels': 'LOC'}]
# []
# []
# [{'text': 'Phoenix', 'labels': 'LOC'}]
# [{'text': 'Mercedes', 'labels': 'MISC'}, {'text': 'Hazelwood', 'labels': 'LOC'}, {'text': 'MO', 'labels': 'LOC'}]
# [{'text': 'Ford Truck', 'labels': 'MISC'}]
# [{'text': 'Mississippi', 'labels': 'LOC'}, {'text': 'Iuka', 'labels': 'LOC'}]
# [{'text': 'Uber', 'labels': 'ORG'}]
# [{'text': 'Tampa', 'labels': 'LOC'}, {'text': 'Florida', 'labels': 'LOC'}]
# [{'text': 'Uber', 'labels': 'ORG'}]
# []
# []
# [{'text': 'Orlando', 'labels': 'LOC'}]
# [{'text': 'Mexican Village Nightclub', 'labels': 'ORG'}, {'text': 'Rochester', 'labels': 'LOC'}, {'text': 'NY', 'labels': 'LOC'}]
# []
# []
# []
# [{'text': 'New Orleans', 'labels': 'LOC'}]
# []
# []
# [{'text': 'Virginia', 'labels': 'LOC'}]
# []
# [{'text': 'Mexican', 'labels': 'MISC'}]
# []
# [{'text': 'Avalon', 'labels': 'LOC'}, {'text': 'South Los Angeles', 'labels': 'LOC'}, {'text': 'AK-47', 'labels': 'MISC'}]
# []
# []
# []
# []
# []
# [{'text': 'Inland Regional Center', 'labels': 'LOC'}, {'text': 'San Bernardino County Department of Public Health', 'labels': 'ORG'}]
# [{'text': 'Planned Parenthood', 'labels': 'ORG'}, {'text': 'Colorado Springs', 'labels': 'LOC'}]
# []
# [{'text': 'Black Lives Matter', 'labels': 'ORG'}, {'text': '4th Precinct', 'labels': 'LOC'}]
# []
# [{'text': 'Northside', 'labels': 'LOC'}, {'text': 'Florida', 'labels': 'LOC'}]
# []
# [{'text': 'Central Maine', 'labels': 'LOC'}]
# []
# [{'text': 'Colerain Township', 'labels': 'LOC'}, {'text': 'Ohio', 'labels': 'LOC'}]
# [{'text': 'Northern Arizona University', 'labels': 'ORG'}, {'text': 'Northern Arizona University', 'labels': 'ORG'}]
# [{'text': 'Oregon', 'labels': 'LOC'}, {'text': 'Snyder Hall', 'labels': 'LOC'}]
# [{'text': 'Good Samaritan', 'labels': 'MISC'}]
# [{'text': 'Meriwether Co.', 'labels': 'LOC'}]
# [{'text': 'South Dakota', 'labels': 'LOC'}]
# [{'text': 'AllNurses.com', 'labels': 'MISC'}]
# []
# [{'text': 'Virginia', 'labels': 'LOC'}, {'text': 'Twitter', 'labels': 'ORG'}]
# [{'text': 'Genesee Street', 'labels': 'LOC'}, {'text': 'Rochester Boys and Girls Club', 'labels': 'ORG'}]
# [{'text': 'Houston', 'labels': 'LOC'}]
# [{'text': 'The Grand 16 Theater', 'labels': 'ORG'}, {'text': 'Lafayette', 'labels': 'LOC'}, {'text': 'Louisiana', 'labels': 'LOC'}, {'text': 'Trainwreck', 'labels': 'MISC'}]
# [{'text': 'Georgia', 'labels': 'LOC'}]
# [{'text': 'Kuwaiti-born', 'labels': 'MISC'}, {'text': 'Mohammod Youssuf Abdulazeez', 'labels': 'PER'}, {'text': 'US', 'labels': 'LOC'}, {'text': 'Naval', 'labels': 'MISC'}, {'text': 'Marines', 'labels': 'ORG'}, {'text': 'Navy', 'labels': 'ORG'}]
# [{'text': 'Marines', 'labels': 'MISC'}, {'text': 'Chattanooga', 'labels': 'LOC'}, {'text': 'Tennessee', 'labels': 'LOC'}]
# [{'text': 'River Forest', 'labels': 'LOC'}]
# [{'text': 'Boom Boom Room', 'labels': 'ORG'}]
# [{'text': 'Dylann Storm Roof', 'labels': 'PER'}, {'text': 'Emanuel AME Church', 'labels': 'ORG'}, {'text': 'Charleston', 'labels': 'LOC'}, {'text': 'South Carolina', 'labels': 'LOC'}]
# [{'text': 'Charleston', 'labels': 'LOC'}, {'text': 'South Carolina', 'labels': 'LOC'}]
# []
# []
# []
# []
# [{'text': 'Club Maxey Monday', 'labels': 'ORG'}]
# []
# [{'text': 'South 16th Street', 'labels': 'LOC'}, {'text': '19th Avenue', 'labels': 'LOC'}, {'text': 'Al-Shakeem Woodson', 'labels': 'PER'}]
# []
# []
# [{'text': 'Gates Pub', 'labels': 'ORG'}]
# [{'text': 'Village West Apartments', 'labels': 'LOC'}]
# []
# [{'text': 'Copeland St.', 'labels': 'LOC'}, {'text': 'Copeland Street', 'labels': 'LOC'}]
# []
# [{'text': 'Bethune-Cookman University', 'labels': 'ORG'}, {'text': 'Daytona Beach', 'labels': 'LOC'}, {'text': 'Bethune-Cookman University', 'labels': 'ORG'}, {'text': 'Daytona Beach', 'labels': 'LOC'}]
# [{'text': 'Tulsa', 'labels': 'LOC'}, {'text': 'Oklahoma', 'labels': 'LOC'}]
# [{'text': 'Spring Break', 'labels': 'MISC'}]
# [{'text': 'New Mexico', 'labels': 'LOC'}, {'text': 'Arizona', 'labels': 'LOC'}]
# []
# []
# []
# [{'text': "Master's Touch", 'labels': 'ORG'}]
# [{'text': 'Facebook', 'labels': 'MISC'}]
# []
# [{'text': "America's Next Top Model", 'labels': 'MISC'}]
# []
# [{'text': 'Fort Hood', 'labels': 'LOC'}]
# [{'text': 'Muslim', 'labels': 'MISC'}]
# [{'text': 'Moon Lake', 'labels': 'LOC'}]
# [{'text': "Macy's", 'labels': 'ORG'}, {'text': 'Monroeville Mall', 'labels': 'LOC'}]
# []
# []
# [{'text': "McAvan's Pub", 'labels': 'LOC'}]
# [{'text': 'Georgia', 'labels': 'LOC'}]
# []
# [{'text': 'Omaha', 'labels': 'LOC'}]
# []
# []
# [{'text': 'Souderton', 'labels': 'LOC'}, {'text': 'Lansdale', 'labels': 'LOC'}, {'text': 'Lower Salford', 'labels': 'LOC'}]
# []
# [{'text': 'Florida State University', 'labels': 'ORG'}]
# [{'text': 'Jaylen Fryberg', 'labels': 'PER'}, {'text': 'Berretta', 'labels': 'MISC'}, {'text': 'Marysville High School', 'labels': 'ORG'}, {'text': 'Fryberg', 'labels': 'PER'}, {'text': 'Fryberg', 'labels': 'PER'}]
# [{'text': 'Marysville-Pilchuck High School', 'labels': 'ORG'}]
# []
# [{'text': 'Bourbon Street', 'labels': 'LOC'}]
# [{'text': 'Las Vegas', 'labels': 'LOC'}, {'text': 'Walmart', 'labels': 'ORG'}, {'text': 'Walmart', 'labels': 'ORG'}]
# [{'text': 'Seattle Pacific University', 'labels': 'ORG'}]
# [{'text': 'Isla Vista', 'labels': 'LOC'}, {'text': 'Isla Vista', 'labels': 'LOC'}, {'text': 'Isla Vista', 'labels': 'LOC'}]
# [{'text': 'FedEx', 'labels': 'ORG'}, {'text': 'Kennesaw', 'labels': 'LOC'}, {'text': 'Georgia', 'labels': 'LOC'}]
# [{'text': 'Fort Hood', 'labels': 'LOC'}]
# []
# [{'text': 'Cherie Lash Rhoades', 'labels': 'PER'}, {'text': 'Cedarville Rancheria Tribal Office and Community Center', 'labels': 'ORG'}, {'text': 'Rhoades', 'labels': 'PER'}]
# []
# []
# [{'text': 'Terminal 3', 'labels': 'LOC'}, {'text': 'Los Angeles International Airport', 'labels': 'ORG'}, {'text': 'LAX', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}, {'text': 'TSA', 'labels': 'ORG'}, {'text': 'TSA', 'labels': 'ORG'}]
# [{'text': 'Sparks Middle School', 'labels': 'ORG'}, {'text': 'Nevada', 'labels': 'LOC'}]
# [{'text': 'Aaron Alexis', 'labels': 'PER'}, {'text': 'Texas', 'labels': 'LOC'}, {'text': 'Navy', 'labels': 'ORG'}]
# [{'text': 'Navy Yard', 'labels': 'ORG'}, {'text': 'Washington D.C', 'labels': 'LOC'}]
# [{'text': 'Selena Gomez', 'labels': 'PER'}]
# [{'text': 'Dallas', 'labels': 'LOC'}]
# [{'text': 'Ross Township', 'labels': 'LOC'}, {'text': 'Salisbury', 'labels': 'LOC'}, {'text': 'Pennsylvania', 'labels': 'LOC'}]
# [{'text': 'Pedro Vargas', 'labels': 'PER'}]
# [{'text': 'Hialeah', 'labels': 'LOC'}, {'text': 'Florida', 'labels': 'LOC'}]
# [{'text': 'John Zawahri', 'labels': 'PER'}, {'text': 'Santa Monica College', 'labels': 'ORG'}]
# [{'text': 'Santa Monica', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}, {'text': 'Santa Monica College', 'labels': 'ORG'}, {'text': 'Santa Monica College', 'labels': 'ORG'}]
# [{'text': 'Manchester', 'labels': 'LOC'}, {'text': 'Illinois', 'labels': 'LOC'}]
# [{'text': 'Dennis Clark III', 'labels': 'PER'}]
# [{'text': 'Federal Way', 'labels': 'LOC'}, {'text': 'Washington', 'labels': 'LOC'}]
# [{'text': 'Kurt Myers', 'labels': 'PER'}]
# [{'text': 'Mohawk', 'labels': 'LOC'}, {'text': 'New York', 'labels': 'LOC'}, {'text': 'Herkimer', 'labels': 'LOC'}]
# []
# [{'text': 'LAPD', 'labels': 'ORG'}, {'text': 'LAPD', 'labels': 'ORG'}, {'text': 'Irvine', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}, {'text': 'San Bernardino Mountains', 'labels': 'LOC'}]
# [{'text': 'Phoenix', 'labels': 'LOC'}, {'text': 'Arizona', 'labels': 'LOC'}]
# [{'text': 'South Valley', 'labels': 'LOC'}, {'text': 'New Mexico', 'labels': 'LOC'}]
# [{'text': 'Adam Lanza', 'labels': 'PER'}, {'text': 'Sandy Hook Elementary', 'labels': 'LOC'}]
# [{'text': 'Newtown', 'labels': 'LOC'}, {'text': 'Connecticut', 'labels': 'LOC'}, {'text': 'Sandy Hook Elementary School', 'labels': 'ORG'}]
# [{'text': 'Clackamas Town Center', 'labels': 'LOC'}, {'text': 'City of Portland', 'labels': 'LOC'}, {'text': 'Oregon', 'labels': 'LOC'}]
# [{'text': 'Azana Spa', 'labels': 'LOC'}, {'text': 'Brookfield', 'labels': 'LOC'}, {'text': 'Wisconsin', 'labels': 'LOC'}]
# [{'text': 'The Spot', 'labels': 'LOC'}]
# [{'text': 'Andrew Engeldinger', 'labels': 'PER'}, {'text': 'UPS', 'labels': 'ORG'}]
# [{'text': 'Accent Signage Systems', 'labels': 'ORG'}, {'text': 'Minneapolis', 'labels': 'LOC'}]
# [{'text': 'U.S. Army', 'labels': 'ORG'}, {'text': 'Wade Michael Page', 'labels': 'PER'}, {'text': 'Sikh', 'labels': 'MISC'}]
# [{'text': 'US Army', 'labels': 'ORG'}, {'text': 'Sikh', 'labels': 'MISC'}, {'text': 'Oak Creek', 'labels': 'LOC'}, {'text': 'Wisconsin', 'labels': 'LOC'}]
# [{'text': 'James Holmes', 'labels': 'PER'}, {'text': 'The Dark Night Rises', 'labels': 'MISC'}]
# [{'text': 'Aurora', 'labels': 'LOC'}]
# [{'text': 'Auburn', 'labels': 'LOC'}, {'text': 'Alabama', 'labels': 'LOC'}, {'text': 'Auburn University', 'labels': 'ORG'}]
# [{'text': 'Seattle', 'labels': 'LOC'}, {'text': 'Washington', 'labels': 'LOC'}]
# [{'text': 'Ian Stawicki', 'labels': 'PER'}, {'text': 'Seattle', 'labels': 'LOC'}]
# [{'text': 'Tulsa', 'labels': 'LOC'}, {'text': 'Oklahoma', 'labels': 'LOC'}]
# [{'text': 'One', 'labels': 'PER'}, {'text': 'L. Goh', 'labels': 'PER'}]
# [{'text': 'Oikos University', 'labels': 'ORG'}, {'text': 'Korean Christian', 'labels': 'MISC'}, {'text': 'Oakland', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}]
# [{'text': 'Chardon High School', 'labels': 'ORG'}, {'text': 'Chardon', 'labels': 'LOC'}, {'text': 'Ohio', 'labels': 'LOC'}]
# [{'text': 'Jeong Soo Paek', 'labels': 'PER'}, {'text': 'Korean', 'labels': 'MISC'}]
# [{'text': 'Paek', 'labels': 'PER'}, {'text': 'Norcross', 'labels': 'LOC'}, {'text': 'Atlanta', 'labels': 'LOC'}, {'text': 'Georgia', 'labels': 'LOC'}]
# []
# [{'text': 'Scott Evans Dekraai', 'labels': 'PER'}]
# [{'text': 'Seal Beach', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}]
# [{'text': 'Eduardo Sencion', 'labels': 'PER'}, {'text': 'International House of Pancakes', 'labels': 'ORG'}]
# [{'text': 'Carson City', 'labels': 'LOC'}, {'text': 'Nevada', 'labels': 'LOC'}, {'text': 'IHOP', 'labels': 'ORG'}]
# []
# [{'text': 'Opelika', 'labels': 'LOC'}, {'text': 'Southern Union State Community College', 'labels': 'ORG'}, {'text': 'Alabama', 'labels': 'LOC'}]
# [{'text': 'Youngstown State University', 'labels': 'ORG'}, {'text': 'Ohio', 'labels': 'LOC'}]
# [{'text': 'Jared Loughner', 'labels': 'PER'}, {'text': 'Safeway', 'labels': 'ORG'}, {'text': 'Gabrielle Giffords', 'labels': 'PER'}, {'text': 'D-Ariz.', 'labels': 'LOC'}]
# [{'text': 'U.S.', 'labels': 'LOC'}, {'text': 'Casas Adobes', 'labels': 'LOC'}, {'text': 'Tucson', 'labels': 'LOC'}, {'text': 'Arizona', 'labels': 'LOC'}]
# [{'text': 'Omar S. Thornton', 'labels': 'PER'}, {'text': 'Hartford Beer Distributor', 'labels': 'ORG'}]
# [{'text': 'Hartford Beer Distributors', 'labels': 'ORG'}, {'text': 'Manchester', 'labels': 'LOC'}, {'text': 'Connecticut', 'labels': 'LOC'}]
# [{'text': 'University of Alabama', 'labels': 'ORG'}, {'text': 'Huntsville', 'labels': 'LOC'}]
# [{'text': 'Maurice Clemmons', 'labels': 'PER'}, {'text': 'Clemmons', 'labels': 'PER'}, {'text': 'Seattle', 'labels': 'LOC'}]
# [{'text': 'Lakewood', 'labels': 'LOC'}, {'text': 'Washington', 'labels': 'LOC'}, {'text': 'Seattle', 'labels': 'LOC'}]
# [{'text': 'Army', 'labels': 'ORG'}, {'text': 'Nidal Malik Hasan', 'labels': 'PER'}, {'text': 'Army', 'labels': 'ORG'}, {'text': 'Islamist', 'labels': 'MISC'}, {'text': 'Hasan', 'labels': 'PER'}]
# [{'text': 'U.S. Army', 'labels': 'ORG'}, {'text': 'Fort Hood Army Base', 'labels': 'LOC'}, {'text': 'Killeen', 'labels': 'LOC'}, {'text': 'Texas', 'labels': 'LOC'}]
# [{'text': 'Jiverly Wong', 'labels': 'PER'}, {'text': 'American Civic Association', 'labels': 'ORG'}]
# [{'text': 'Binghamton', 'labels': 'LOC'}, {'text': 'New York', 'labels': 'LOC'}]
# [{'text': 'Robert Stewart', 'labels': 'PER'}]
# [{'text': 'Yahoo!', 'labels': 'ORG'}, {'text': 'Santa Clara', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}]
# [{'text': 'Pinelake Health and Rehab', 'labels': 'ORG'}, {'text': 'Carthage', 'labels': 'LOC'}, {'text': 'North Carolina', 'labels': 'LOC'}]
# [{'text': 'Geneva County', 'labels': 'LOC'}, {'text': 'Alabama', 'labels': 'LOC'}]
# [{'text': 'Covina', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}, {'text': 'Santa Claus', 'labels': 'PER'}]
# [{'text': 'University of Central Arkansas', 'labels': 'ORG'}, {'text': 'Conway', 'labels': 'LOC'}, {'text': 'Arkansas', 'labels': 'LOC'}]
# [{'text': 'South Mountain Community College', 'labels': 'ORG'}, {'text': 'Phoenix', 'labels': 'LOC'}, {'text': 'Arizona', 'labels': 'LOC'}]
# [{'text': 'Wesley Neal Higdon', 'labels': 'PER'}, {'text': 'Atlantis Plastics', 'labels': 'ORG'}, {'text': 'Higdon', 'labels': 'PER'}]
# [{'text': 'Atlantis Plastics', 'labels': 'ORG'}, {'text': 'Henderson', 'labels': 'LOC'}, {'text': 'Kentucky', 'labels': 'LOC'}]
# [{'text': 'Steven Kazmierczak', 'labels': 'PER'}]
# [{'text': 'Northern Illinois University', 'labels': 'ORG'}, {'text': 'Dekalb', 'labels': 'LOC'}, {'text': 'Illinois', 'labels': 'LOC'}]
# [{'text': 'Charles "Cookie" Lee Thornton', 'labels': 'PER'}]
# [{'text': 'City Hall', 'labels': 'ORG'}, {'text': 'Kirkwood', 'labels': 'LOC'}, {'text': 'Missouri', 'labels': 'LOC'}]
# [{'text': 'Carnation', 'labels': 'LOC'}, {'text': 'Washington', 'labels': 'LOC'}]
# [{'text': 'Mojave High School', 'labels': 'ORG'}, {'text': 'Las Vegas', 'labels': 'LOC'}, {'text': 'Nevada', 'labels': 'LOC'}, {'text': 'Denver', 'labels': 'LOC'}, {'text': 'CO', 'labels': 'LOC'}, {'text': 'Chicago', 'labels': 'LOC'}]
# [{'text': 'Youth With A Mission', 'labels': 'ORG'}, {'text': 'Arvada', 'labels': 'LOC'}, {'text': 'Colorado', 'labels': 'LOC'}, {'text': 'New Life Church', 'labels': 'ORG'}]
# [{'text': 'Robert A. Hawkins', 'labels': 'PER'}, {'text': 'Westroads Mall', 'labels': 'ORG'}]
# [{'text': 'Omaha', 'labels': 'LOC'}, {'text': 'Nebraska', 'labels': 'LOC'}, {'text': 'Westroads Mall', 'labels': 'ORG'}]
# [{'text': 'South Middle School', 'labels': 'ORG'}, {'text': 'Saginaw', 'labels': 'LOC'}, {'text': 'Michigan', 'labels': 'LOC'}]
# [{'text': 'SuccessTech Academy', 'labels': 'ORG'}, {'text': 'Cleveland', 'labels': 'LOC'}, {'text': 'Ohio', 'labels': 'LOC'}]
# [{'text': 'Tyler Peterson', 'labels': 'PER'}]
# []
# [{'text': 'Virginia Tech', 'labels': 'ORG'}, {'text': 'Seung-Hui Cho', 'labels': 'PER'}]
# [{'text': 'Virginia Tech', 'labels': 'ORG'}, {'text': 'Blacksburg', 'labels': 'LOC'}, {'text': 'Virginia', 'labels': 'LOC'}]
# [{'text': 'Springwater Trail High School', 'labels': 'ORG'}, {'text': 'Gresham', 'labels': 'LOC'}, {'text': 'Oregon', 'labels': 'LOC'}]
# [{'text': 'Sulejman TaloviÄ', 'labels': 'PER'}]
# [{'text': 'Salt Lake City', 'labels': 'LOC'}, {'text': 'Utah', 'labels': 'LOC'}, {'text': 'Trolley Square', 'labels': 'LOC'}]
# [{'text': 'Charles Carl Roberts', 'labels': 'PER'}, {'text': 'Bart Township', 'labels': 'LOC'}]
# [{'text': 'West Nickel Amish School', 'labels': 'ORG'}, {'text': 'Nickel Mines', 'labels': 'LOC'}, {'text': 'Pennsylvania', 'labels': 'LOC'}]
# [{'text': 'Duquesne University', 'labels': 'ORG'}]
# [{'text': 'Orange High School', 'labels': 'ORG'}, {'text': 'Hillsborough', 'labels': 'LOC'}, {'text': 'North Carolina', 'labels': 'LOC'}]
# [{'text': 'Essex Junction', 'labels': 'LOC'}, {'text': 'Vermont', 'labels': 'LOC'}]
# [{'text': 'Kyle Aaron Huff', 'labels': 'PER'}, {'text': 'Capitol Hill', 'labels': 'LOC'}, {'text': 'Seattle', 'labels': 'LOC'}]
# [{'text': 'Capitol Hill', 'labels': 'LOC'}, {'text': 'Seattle', 'labels': 'LOC'}, {'text': 'Washington', 'labels': 'LOC'}]
# [{'text': 'Jennifer Sanmarco', 'labels': 'PER'}]
# [{'text': 'Goleta Post Office', 'labels': 'ORG'}, {'text': 'Goleta', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}]
# [{'text': 'Jeffrey Weise', 'labels': 'PER'}, {'text': 'Weise', 'labels': 'PER'}, {'text': 'Red Lake Senior High School', 'labels': 'ORG'}]
# [{'text': 'Red Lake High School', 'labels': 'ORG'}, {'text': 'Red Lake', 'labels': 'LOC'}, {'text': 'Minnesota', 'labels': 'LOC'}]
# [{'text': 'Living Church of God', 'labels': 'ORG'}, {'text': 'Terry Michael Ratzmann', 'labels': 'PER'}, {'text': 'Sheraton', 'labels': 'ORG'}]
# [{'text': 'Brookfield', 'labels': 'LOC'}, {'text': 'Wisconsin', 'labels': 'LOC'}, {'text': 'Living Church of God', 'labels': 'ORG'}]
# [{'text': 'Smith County Courthouse', 'labels': 'LOC'}, {'text': 'Texas', 'labels': 'LOC'}]
# [{'text': 'Nathan Gale', 'labels': 'PER'}, {'text': 'Pantera', 'labels': 'ORG'}, {'text': 'Pantera', 'labels': 'ORG'}, {'text': 'Dimebag Darrell', 'labels': 'PER'}, {'text': 'Damageplan', 'labels': 'ORG'}, {'text': 'Gale', 'labels': 'PER'}]
# [{'text': 'US Marine Corps', 'labels': 'ORG'}, {'text': 'Damageplan', 'labels': 'ORG'}, {'text': 'Alrosa Villa Nightclub', 'labels': 'ORG'}, {'text': 'Columbus', 'labels': 'LOC'}, {'text': 'Ohio', 'labels': 'LOC'}, {'text': 'Pantera', 'labels': 'ORG'}]
# [{'text': 'Birchwood', 'labels': 'LOC'}, {'text': 'Wisconsin', 'labels': 'LOC'}]
# [{'text': 'Windy City Core Supply', 'labels': 'ORG'}, {'text': 'Chicago', 'labels': 'LOC'}, {'text': 'Illinois', 'labels': 'LOC'}]
# [{'text': 'Douglas Williams', 'labels': 'PER'}, {'text': 'Lockheed Martin', 'labels': 'ORG'}]
# [{'text': 'Lockheed Martin', 'labels': 'ORG'}, {'text': 'Meridian', 'labels': 'LOC'}, {'text': 'Mississippi', 'labels': 'LOC'}]
# [{'text': 'Case Western Reserve University', 'labels': 'ORG'}, {'text': 'Cleveland', 'labels': 'LOC'}, {'text': 'Ohio', 'labels': 'LOC'}]
# [{'text': 'University of Arizona College of Nursing', 'labels': 'ORG'}, {'text': 'Tucson', 'labels': 'LOC'}, {'text': 'Arizona', 'labels': 'LOC'}]
# [{'text': 'Appalachian School of Law', 'labels': 'ORG'}, {'text': 'Grundy', 'labels': 'LOC'}, {'text': 'Virginia', 'labels': 'LOC'}]
# [{'text': 'Santana High School', 'labels': 'ORG'}, {'text': 'San Diego', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}]
# [{'text': 'William D. Baker', 'labels': 'PER'}, {'text': 'Navistar', 'labels': 'ORG'}]
# [{'text': 'Navistar', 'labels': 'ORG'}, {'text': 'Melrose Park', 'labels': 'LOC'}, {'text': 'Illinois', 'labels': 'LOC'}]
# [{'text': 'Michael McDermott', 'labels': 'PER'}, {'text': 'Edgewater Technology', 'labels': 'ORG'}]
# [{'text': 'Edgewater Technology', 'labels': 'ORG'}, {'text': 'Wakefield', 'labels': 'LOC'}, {'text': 'Massachusetts', 'labels': 'LOC'}, {'text': 'Nazis', 'labels': 'MISC'}]
# [{'text': 'Silvio Leyva', 'labels': 'PER'}, {'text': 'Radisson Bay Harbor Inn', 'labels': 'ORG'}]
# [{'text': 'Radisson Bay Harbor Inn', 'labels': 'ORG'}, {'text': 'Tampa', 'labels': 'LOC'}, {'text': 'Florida', 'labels': 'LOC'}]
# [{'text': 'Fort Gibson Middle School', 'labels': 'ORG'}, {'text': 'Fort Gibson', 'labels': 'LOC'}, {'text': 'Oklahoma', 'labels': 'LOC'}]
# [{'text': 'Byran Koji Uyesugi', 'labels': 'PER'}, {'text': 'Xerox', 'labels': 'ORG'}, {'text': '9mm Glock', 'labels': 'MISC'}]
# [{'text': 'Xerox', 'labels': 'ORG'}, {'text': 'Honolulu', 'labels': 'LOC'}, {'text': 'Hawaii', 'labels': 'LOC'}, {'text': 'Honolulu', 'labels': 'LOC'}]
# [{'text': 'Larry Gene Ashbrook', 'labels': 'PER'}, {'text': 'Wedgwood Baptist Church', 'labels': 'LOC'}]
# [{'text': 'Wedgwood Baptist Church', 'labels': 'LOC'}, {'text': 'Fort Worth', 'labels': 'LOC'}, {'text': 'Texas', 'labels': 'LOC'}]
# [{'text': 'Mark O. Barton', 'labels': 'PER'}, {'text': 'All-Tech Investment Group', 'labels': 'ORG'}, {'text': 'Momentum Securities', 'labels': 'ORG'}]
# [{'text': 'Atlanta', 'labels': 'LOC'}, {'text': 'Georgia', 'labels': 'LOC'}]
# [{'text': 'Heritage High School', 'labels': 'ORG'}, {'text': 'Conyers', 'labels': 'LOC'}, {'text': 'Georgia', 'labels': 'LOC'}]
# [{'text': 'Eric Harris', 'labels': 'PER'}, {'text': 'Dylan Klebold', 'labels': 'PER'}, {'text': 'Columbine High School', 'labels': 'ORG'}]
# [{'text': 'Columbine High School', 'labels': 'ORG'}, {'text': 'Littleton', 'labels': 'LOC'}, {'text': 'Colorado', 'labels': 'LOC'}]
# [{'text': 'U.S. Postal Service', 'labels': 'ORG'}, {'text': 'City Hall', 'labels': 'ORG'}, {'text': 'Riverside', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}]
# [{'text': 'Kipland P. Kinkel', 'labels': 'PER'}, {'text': 'Thurston High', 'labels': 'ORG'}, {'text': 'Kipland', 'labels': 'PER'}]
# [{'text': 'Thurston High School', 'labels': 'ORG'}, {'text': 'Springfield', 'labels': 'LOC'}, {'text': 'Oregon', 'labels': 'LOC'}]
# [{'text': 'Park Middle School', 'labels': 'ORG'}, {'text': 'Edinboro', 'labels': 'LOC'}, {'text': 'Pennsylvania', 'labels': 'LOC'}]
# [{'text': 'Mitchell Scott Johnson', 'labels': 'PER'}, {'text': 'Andrew Douglas Golden', 'labels': 'PER'}]
# [{'text': 'Westside Middle School', 'labels': 'ORG'}, {'text': 'Jonesboro', 'labels': 'LOC'}, {'text': 'Arkansas', 'labels': 'LOC'}]
# [{'text': 'Matthew Beck', 'labels': 'PER'}]
# [{'text': 'State Lottery', 'labels': 'ORG'}, {'text': 'Newington', 'labels': 'LOC'}, {'text': 'Connecticut', 'labels': 'LOC'}]
# [{'text': 'Milwaukee', 'labels': 'LOC'}, {'text': 'Wisconsin', 'labels': 'LOC'}]
# [{'text': 'Caltrans', 'labels': 'ORG'}, {'text': 'Arturo Reyes Torres', 'labels': 'PER'}]
# [{'text': 'Caltrans', 'labels': 'ORG'}]
# [{'text': 'Heath High School', 'labels': 'ORG'}, {'text': 'West Paducah', 'labels': 'LOC'}, {'text': 'Kentucky', 'labels': 'LOC'}]
# [{'text': 'Pearl High School', 'labels': 'ORG'}, {'text': 'Pearl', 'labels': 'LOC'}, {'text': 'Mississippi', 'labels': 'LOC'}]
# [{'text': 'Hastings', 'labels': 'LOC'}, {'text': 'Arthur Wise', 'labels': 'PER'}, {'text': 'R.E. Phelon Company', 'labels': 'ORG'}, {'text': 'South Carolina', 'labels': 'LOC'}]
# [{'text': 'R.E. Phelon Company', 'labels': 'ORG'}, {'text': 'Aiken', 'labels': 'LOC'}, {'text': 'South Carolina', 'labels': 'LOC'}]
# [{'text': 'Bethel Regional High School', 'labels': 'ORG'}, {'text': 'Bethel', 'labels': 'LOC'}, {'text': 'Alaska', 'labels': 'LOC'}]
# [{'text': 'San Diego State University', 'labels': 'ORG'}, {'text': 'San Diego', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}]
# [{'text': 'Clifton McCree', 'labels': 'PER'}]
# [{'text': 'Fort Lauderdale', 'labels': 'LOC'}, {'text': 'Florida', 'labels': 'LOC'}]
# [{'text': 'Frontier Junior High School', 'labels': 'ORG'}, {'text': 'Moses Lake', 'labels': 'LOC'}, {'text': 'Washington', 'labels': 'LOC'}]
# [{'text': 'Richland High School', 'labels': 'ORG'}, {'text': 'Lynnville', 'labels': 'LOC'}, {'text': 'Tennessee', 'labels': 'LOC'}]
# [{'text': 'James Daniel Simpson', 'labels': 'PER'}, {'text': 'Walter Rossler Company', 'labels': 'ORG'}]
# [{'text': 'Walter Rossler Company', 'labels': 'ORG'}, {'text': 'Corpus Christi', 'labels': 'LOC'}, {'text': 'Texas', 'labels': 'LOC'}]
# [{'text': 'Montclair', 'labels': 'LOC'}, {'text': 'New Jersey', 'labels': 'LOC'}]
# [{'text': 'Chapel Hill', 'labels': 'LOC'}, {'text': 'North Carolina', 'labels': 'LOC'}]
# [{'text': 'Planned Parenthood', 'labels': 'ORG'}, {'text': 'Preterm Health Services', 'labels': 'ORG'}]
# [{'text': 'Wickliffe Middle School', 'labels': 'ORG'}, {'text': 'Wickliffe', 'labels': 'LOC'}, {'text': 'Ohio', 'labels': 'LOC'}]
# [{'text': 'Dean Allen Mellberg', 'labels': 'PER'}, {'text': 'Fairchild Air Force Base', 'labels': 'LOC'}]
# [{'text': 'Fairchild Air Force Base Hospital', 'labels': 'LOC'}, {'text': 'Spokane', 'labels': 'LOC'}, {'text': 'Washington', 'labels': 'LOC'}]
# []
# [{'text': 'Chelsea High School', 'labels': 'ORG'}, {'text': 'Chelsea', 'labels': 'LOC'}, {'text': 'Michigan', 'labels': 'LOC'}]
# [{'text': 'Nathan Dunlap', 'labels': 'PER'}, {'text': 'Chuck E. Cheese', 'labels': 'ORG'}]
# [{'text': 'Chuck E. Cheese', 'labels': 'PER'}, {'text': 'Aurora', 'labels': 'LOC'}, {'text': 'Colorado', 'labels': 'LOC'}]
# [{'text': 'Colin Ferguson', 'labels': 'PER'}, {'text': 'Long Island Rail Road', 'labels': 'LOC'}, {'text': 'Garden City', 'labels': 'LOC'}]
# [{'text': 'Lond Island Rail Road', 'labels': 'LOC'}, {'text': 'Nassau County', 'labels': 'LOC'}, {'text': 'New York', 'labels': 'LOC'}]
# [{'text': 'Navy', 'labels': 'ORG'}, {'text': 'Central Middle School', 'labels': 'ORG'}, {'text': 'Sheridan', 'labels': 'LOC'}, {'text': 'Wyoming', 'labels': 'LOC'}]
# [{'text': 'Kenneth Junior French', 'labels': 'PER'}, {'text': 'Luigi', 'labels': 'PER'}, {'text': 'Italian', 'labels': 'MISC'}]
# [{'text': "Luigi's Restaurant", 'labels': 'ORG'}, {'text': 'Fayetteville', 'labels': 'LOC'}, {'text': 'North Carolina', 'labels': 'LOC'}]
# [{'text': 'Weber State University', 'labels': 'ORG'}, {'text': 'Odgen', 'labels': 'LOC'}, {'text': 'Utah', 'labels': 'LOC'}, {'text': 'State', 'labels': 'ORG'}]
# [{'text': 'Gian Luigi Ferri', 'labels': 'PER'}]
# [{'text': 'Pettit & Martin', 'labels': 'ORG'}, {'text': 'San Francisco', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}]
# [{'text': 'Dearborn', 'labels': 'LOC'}, {'text': 'Michigan', 'labels': 'LOC'}]
# [{'text': 'Dana Point', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}]
# [{'text': "Simon's Rock College of Bard", 'labels': 'ORG'}, {'text': 'Great Barrington', 'labels': 'LOC'}, {'text': 'Massachusetts', 'labels': 'LOC'}]
# [{'text': 'John T. Miller', 'labels': 'PER'}, {'text': 'Miller', 'labels': 'PER'}]
# [{'text': 'Schuyler County Office Building', 'labels': 'LOC'}, {'text': 'Watkins Glen', 'labels': 'LOC'}, {'text': 'New York', 'labels': 'LOC'}]
# [{'text': 'Amarillo', 'labels': 'LOC'}, {'text': 'Texas', 'labels': 'LOC'}]
# [{'text': 'Lindhurst High School', 'labels': 'ORG'}, {'text': 'Eric Houston', 'labels': 'PER'}]
# [{'text': 'Lindhurst High School', 'labels': 'ORG'}, {'text': 'Olivehurst', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}]
# [{'text': 'Thomas McIlvane', 'labels': 'PER'}]
# [{'text': 'Royal Oak', 'labels': 'LOC'}, {'text': 'Michigan', 'labels': 'LOC'}]
# [{'text': 'Gang Lu', 'labels': 'PER'}]
# [{'text': 'University of Iowa', 'labels': 'ORG'}, {'text': 'Iowa City', 'labels': 'LOC'}]
# [{'text': 'George Hennard', 'labels': 'PER'}, {'text': 'Luby', 'labels': 'ORG'}]
# [{'text': "Luby's Cafeteria", 'labels': 'ORG'}, {'text': 'Killeen', 'labels': 'LOC'}, {'text': 'Texas', 'labels': 'LOC'}]
# [{'text': 'Ridgewood', 'labels': 'LOC'}, {'text': 'New Jersey', 'labels': 'LOC'}]
# [{'text': 'Air Force', 'labels': 'ORG'}, {'text': 'ROTC', 'labels': 'MISC'}, {'text': 'Buddhist', 'labels': 'MISC'}]
# [{'text': 'James Edward Pough', 'labels': 'PER'}, {'text': 'General Motors Acceptance Corporation', 'labels': 'ORG'}, {'text': 'Pough', 'labels': 'PER'}]
# [{'text': 'General Motors Acceptance Corporation', 'labels': 'ORG'}, {'text': 'Jacksonville', 'labels': 'LOC'}, {'text': 'Florida', 'labels': 'LOC'}]
# [{'text': 'Joseph T. Wesbecker', 'labels': 'PER'}]
# [{'text': 'Standard Gravure', 'labels': 'ORG'}, {'text': 'Louisville', 'labels': 'LOC'}, {'text': 'Kentucky', 'labels': 'LOC'}]
# [{'text': 'Orange Glen Post Office', 'labels': 'ORG'}, {'text': 'Escondido', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}]
# [{'text': 'Patrick Purdy', 'labels': 'PER'}, {'text': 'Cleveland Elementary School', 'labels': 'ORG'}, {'text': 'Southeast Asian', 'labels': 'MISC'}, {'text': 'Purdy', 'labels': 'PER'}]
# [{'text': 'Cleveland Elementary School', 'labels': 'ORG'}, {'text': 'Stockton', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}]
# [{'text': 'New Orleans', 'labels': 'LOC'}, {'text': 'Louisiana', 'labels': 'LOC'}, {'text': 'FBI', 'labels': 'ORG'}, {'text': 'FBI', 'labels': 'ORG'}]
# [{'text': 'Oakland Elementary School', 'labels': 'ORG'}, {'text': 'Greenwood', 'labels': 'LOC'}, {'text': 'South Carolina', 'labels': 'LOC'}]
# [{'text': 'Vietnam', 'labels': 'LOC'}, {'text': 'Comet Auto Parts', 'labels': 'ORG'}, {'text': 'Chicago', 'labels': 'LOC'}, {'text': 'Illinois', 'labels': 'LOC'}, {'text': 'Montefiore School', 'labels': 'ORG'}]
# [{'text': 'Hubbard Woods Elementary School', 'labels': 'ORG'}]
# [{'text': 'ESL Incorporated', 'labels': 'ORG'}, {'text': 'Richard Farley', 'labels': 'PER'}, {'text': 'San Quentin', 'labels': 'LOC'}]
# [{'text': 'ESL', 'labels': 'ORG'}, {'text': 'Sunnyvale', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}]
# []
# [{'text': 'William Cruse', 'labels': 'PER'}, {'text': 'Publix', 'labels': 'ORG'}, {'text': 'Florida Tech', 'labels': 'ORG'}, {'text': 'Winn-Dixie', 'labels': 'LOC'}, {'text': 'Cruse', 'labels': 'PER'}]
# [{'text': 'Palm Bay', 'labels': 'LOC'}, {'text': 'Florida', 'labels': 'LOC'}]
# [{'text': 'Fergus County High School', 'labels': 'ORG'}, {'text': 'Lewistown', 'labels': 'LOC'}, {'text': 'Montana', 'labels': 'LOC'}]
# [{'text': 'Patrick Sherrill', 'labels': 'PER'}]
# [{'text': 'Edmond', 'labels': 'LOC'}, {'text': 'Oklahoma', 'labels': 'LOC'}]
# [{'text': 'New York Technical College', 'labels': 'ORG'}, {'text': 'Brooklyn', 'labels': 'LOC'}]
# [{'text': 'Atlanta Post Office', 'labels': 'ORG'}]
# [{'text': 'Goddard Junior High School', 'labels': 'ORG'}, {'text': 'Goddard', 'labels': 'LOC'}, {'text': 'Kansas', 'labels': 'LOC'}, {'text': 'Goddard', 'labels': 'LOC'}]
# [{'text': 'James Oliver Huberty', 'labels': 'PER'}, {'text': "McDonald's", 'labels': 'ORG'}]
# [{'text': "McDonald's", 'labels': 'ORG'}, {'text': 'San Ysidro', 'labels': 'LOC'}, {'text': 'California', 'labels': 'LOC'}]
# [{'text': 'Abdelkrim Belachheb', 'labels': 'PER'}]
# [{'text': "Ianni's Dance Club", 'labels': 'ORG'}, {'text': 'Dallas', 'labels': 'LOC'}, {'text': 'Texas', 'labels': 'LOC'}]

# %%
with open('mass_shootings.json', 'w') as json_file:
    json.dump(output, json_file, indent=4)
